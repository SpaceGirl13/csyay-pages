// %% [raw]
// ---
// layout: post
// title: 1.7 Application Program Interface (API) and Libraries
// description: Boba Cafe Series, Lesson 7. Libraries, APIs, packages and imports, and identifying the attributes and behaviors of a class from its documentation.
// categories: [AP CSA, Unit 1]
// permalink: /csa/unit1/1-7
// toc: true
// comments: true
// ---

// %% [markdown]
// # 1.7 — API and Libraries 🧋
//
// ### AP CSA · Unit 1: Using Objects and Methods
// **Boba Cafe Series · Lesson 7**
//
// ---
//
// > **Setup note:** every code cell runs on the **IJava kernel** (Java 17+). Check that the kernel picker says *Java*. Each cell declares a class and then calls it with `ClassName.main(null);`.

// %% [markdown]
// ## You've been borrowing tools this whole time
//
// Look back at any program you've written in this series. Every single one contains this:
//
// ```java
// System.out.println("...");
// ```
//
// You never wrote `System`. You never wrote `println`. You didn't define `Scanner` in 1.4, or `Integer.MAX_VALUE` in 1.5. You just *used* them, and they worked.
//
// Where did they come from?
//
// Byte-Sized Boba doesn't grow its own tea leaves, mill its own cups, or manufacture its own sealing machine. It orders from **suppliers**. What the cafe actually does is combine those supplied parts into drinks nobody else makes.
//
// Programming works the same way. Java ships with thousands of pre-written, pre-tested classes, and your job is almost never to rebuild them — it's to know what's in the catalog and how to order from it.
//
// This lesson has less code than the last six. That's deliberate. **The skill here is reading, not typing** — and it's the skill that separates "I know Java syntax" from "I can build things."
//
// ### What you'll be able to do by the end
//
// | # | Objective | CED reference |
// |---|---|---|
// | 1 | Explain what a **library** is and why libraries exist | 1.7.A |
// | 2 | Explain what an **API** is and how it differs from an implementation | 1.7.A |
// | 3 | Identify the **attributes** and **behaviors** of a class from its documentation | 1.7.A |
// | 4 | Explain packages and when an `import` statement is required | 1.7.A |
// | 5 | Use an unfamiliar class correctly using only its documentation | 1.7.A |

// %% [markdown]
// ---
//
// ## Part 1 — Libraries
//
// > **Definition:** A **library** is a collection of pre-written classes that you can use in your own programs.
//
// Java's **standard library** comes bundled with Java itself. You don't install it, download it, or pay for it — it's already there, which is why `System.out.println` worked on day one without any setup.
//
// Three reasons this matters more than it might sound:
//
// | Reason | The cafe version |
// |---|---|
// | **Don't reinvent** | You don't build a milk steamer from scratch to open a cafe |
// | **Already tested** | The supplier's steamer has been used by ten thousand shops; yours has been used by you |
// | **Everyone knows it** | Any barista you hire already knows how a standard steamer works |
//
// That last one is easy to underestimate. When you write `Math.sqrt(x)`, every Java programmer on earth instantly knows what that does. If you wrote your own `mySquareRootThing(x)`, nobody would — including you, six months later.

// %% [markdown]
// ---
//
// ## Part 2 — What an API actually is
//
// **API** stands for **Application Program Interface**.
//
// > **Definition:** An **API** is the documented description of what a class provides and how to use it — its available methods, what they need, and what they give back.
//
// Here's the part that trips people up: **an API tells you what a class does, not how it does it.**
//
// Think about the cafe menu. It tells a customer:
//
// - what they can order (Taro Milk Tea)
// - what they have to supply (a size choice, $5.75)
// - what they'll get back (a sealed cup of taro milk tea)
//
// It does **not** tell them the steeping time, the brand of tapioca, or how the sealing machine works. The customer doesn't need any of that — and the cafe can switch tapioca suppliers without reprinting a single menu.
//
// That separation is called **abstraction**, and it's one of the most important ideas in the whole course.
//
// ```
//    WHAT YOU SEE (the API)              WHAT'S HIDDEN (the implementation)
//  ┌──────────────────────────┐        ┌────────────────────────────────┐
//  │  Math.sqrt(double x)     │        │  hundreds of lines of numerical│
//  │  Returns the square root │───────►│  approximation code you never  │
//  │  of x                    │        │  have to read or understand    │
//  └──────────────────────────┘        └────────────────────────────────┘
// ```
//
// You have used `Math.sqrt` with total confidence and zero idea how square roots are computed in binary. That's not laziness — **that's the API doing its job.**

// %%
public class Abstraction {
    public static void main(String[] args) {
        // You know exactly WHAT this does.
        // You have no idea HOW, and you don't need to.
        System.out.println("Square root of 144: " + Math.sqrt(144));
        System.out.println("Square root of 2:   " + Math.sqrt(2));

        System.out.println();
        System.out.println("Two calls. Zero knowledge of the algorithm required.");
    }
}

Abstraction.main(null);

// %% [markdown]
// ---
//
// ## Part 3 — Attributes and behaviors
//
// This is the actual learning objective, so slow down here.
//
// Every class describes two kinds of things:
//
// | | **Attributes** | **Behaviors** |
// |---|---|---|
// | Also called | Data, state, fields, variables | Methods, operations |
// | Question it answers | *What does it **know**?* | *What can it **do**?* |
// | In code | Variables belonging to the class | Methods belonging to the class |
//
// For a drink at the cafe:
//
// ```
//         BobaDrink
//  ┌───────────────────────────┐
//  │ ATTRIBUTES (what it knows)│
//  │   flavor      "Taro"      │
//  │   sizeOunces  16          │
//  │   sugarLevel  50          │
//  │   hasPearls   true        │
//  │   price       5.75        │
//  ├───────────────────────────┤
//  │ BEHAVIORS (what it does)  │
//  │   addTopping()            │
//  │   setSugarLevel()         │
//  │   getPrice()              │
//  │   seal()                  │
//  └───────────────────────────┘
// ```
//
// A quick test that almost always works: **attributes are nouns, behaviors are verbs.** `price` is a thing the drink knows. `seal()` is a thing the drink does.
//
// You can spot both in classes you've already used:

// %%
public class AttributesAndBehaviors {
    public static void main(String[] args) {
        // ATTRIBUTES -- values the class KNOWS. No parentheses.
        System.out.println("Integer.MAX_VALUE  (attribute): " + Integer.MAX_VALUE);
        System.out.println("Integer.MIN_VALUE  (attribute): " + Integer.MIN_VALUE);

        System.out.println();

        // BEHAVIORS -- things the class DOES. Parentheses, usually with input.
        System.out.println("Math.abs(-7)       (behavior):  " + Math.abs(-7));
        System.out.println("Math.pow(2, 5)     (behavior):  " + Math.pow(2, 5));
        System.out.println("Math.sqrt(144)     (behavior):  " + Math.sqrt(144));
    }
}

AttributesAndBehaviors.main(null);

// %% [markdown]
// Notice the syntax difference, which is a reliable giveaway:
//
// - `Integer.MAX_VALUE` — **no parentheses**. You're reading a stored value.
// - `Math.sqrt(144)` — **parentheses**, with something inside. You're asking it to *do* something.
//
// > You'll write your own classes with your own attributes and behaviors in **Unit 3**. Right now you only need to identify them in classes somebody else wrote.

// %% [markdown]
// ---
//
// ## Part 4 — Packages and `import`
//
// Java's standard library is enormous, so it's organized into **packages** — like aisles in a supply warehouse.
//
// | Package | Contains | Import needed? |
// |---|---|---|
// | `java.lang` | `String`, `Math`, `System`, `Integer`, `Double`, `Object` | **No** — automatic |
// | `java.util` | `Scanner`, `ArrayList` | **Yes** |
// | `java.io` | `File` | **Yes** |
//
// `java.lang` is imported into every Java program automatically, because its contents are so fundamental. That's the answer to the question at the top of this notebook: **`System` worked on day one because `System` lives in `java.lang`.**
//
// Everything else you have to ask for:
//
// ```java
// import java.util.Scanner;        // one specific class
// import java.util.*;              // every class in the package
// ```
//
// The `import` goes **above** the class declaration, at the very top of the file. Importing a class you never use is harmless; using a class you never imported is a compile-time error.

// %%
import java.util.Scanner;

public class ProperImport {
    public static void main(String[] args) {
        // Scanner is from java.util, so the import above is required
        Scanner scan = new Scanner("Taro 3 5.75");

        System.out.println("Flavor:   " + scan.next());
        System.out.println("Quantity: " + scan.nextInt());
        System.out.println("Price:    $" + scan.nextDouble());

        scan.close();

        // Math and Integer are from java.lang -- no import, they just work
        System.out.println("Also available with no import: " + Math.sqrt(64));
    }
}

ProperImport.main(null);

// %% [markdown]
// ### What forgetting the import looks like
//
// If you write this in a real `.java` file:
//
// ```java
// public class NoImport {
//     public static void main(String[] args) {
//         Scanner scan = new Scanner("Taro 3");     // no import above!
//     }
// }
// ```
//
// the compiler stops you before anything runs:
//
// ```
// NoImport.java:3: error: cannot find symbol
//         Scanner scan = new Scanner("Taro 3");
//         ^
//   symbol:   class Scanner
//   location: class NoImport
// ```
//
// **"Cannot find symbol" on a class name almost always means a missing import.** It's one of the most common errors beginners hit, and once you recognize the message it takes five seconds to fix.
//
// > **An honest caveat about this notebook.** Jupyter's Java kernel automatically pre-imports several common packages, including `java.util`, as a convenience. That means a cell using `Scanner` without an `import` may run just fine *here* while failing in a real `.java` file.
// >
// > This is why the example above is shown as text rather than as a runnable cell — it would not reliably fail for you. **Always write the `import` anyway.** Your notebook is being generous; the AP exam and every real compiler will not be.

// %% [markdown]
// ---
//
// ## Part 5 — How to read an API entry
//
// Documentation entries look intimidating until you know they always have the same four parts.
//
// ```
//    static double pow(double base, double exponent)
//    ^^^^^^ ^^^^^^ ^^^  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
//      |      |     |              |
//      |      |     |              └─ PARAMETERS: what you must supply
//      |      |     └─ NAME: what you call it
//      |      └─ RETURN TYPE: what type comes back
//      └─ static: call it on the class itself (Math.pow), not on an object
// ```
//
// Read it as a sentence: *"`pow` needs two doubles, and gives you back a double."*
//
// Then the description tells you the meaning: *"Returns the value of the first parameter raised to the power of the second."*
//
// ### Practice: the `Math` class
//
// Here are four real entries you can use on the AP exam:
//
// | Entry | What it does |
// |---|---|
// | `static int abs(int x)` | Returns the absolute value of `x` |
// | `static double abs(double x)` | Returns the absolute value of `x` |
// | `static double pow(double base, double exponent)` | Returns `base` raised to the `exponent` |
// | `static double sqrt(double x)` | Returns the positive square root of `x` |
// | `static double random()` | Returns a `double` that is at least `0.0` and less than `1.0` |
//
// Two things to notice:
//
// 1. **`abs` appears twice.** Same name, different parameter types, different return types. Java picks the right one based on what you pass it. That's why `Math.abs(-7)` gave you `7` (an `int`) rather than `7.0`.
// 2. **`random()` has empty parentheses.** It needs nothing from you, but it's still a behavior — it *does* something — so the parentheses stay.
//
// > The full list of classes and methods you may use on the exam is called the **AP Java Quick Reference**, and it's provided to you during the exam. You don't have to memorize method lists. You *do* have to be able to read them fluently.

// %%
public class ReadingTheDocs {
    public static void main(String[] args) {
        // static double sqrt(double x)  -> give it a double, get a double
        double side = Math.sqrt(64);
        System.out.println("A square counter of area 64 has sides of " + side + " ft");

        // static double pow(double base, double exponent)  -> two doubles in, one out
        System.out.println("2 to the 10th power: " + Math.pow(2, 10));

        // static int abs(int x)  -> int in, INT out (note: no .0)
        System.out.println("Register off by: " + Math.abs(237 - 250) + " dollars");

        // static double abs(double x)  -> double in, DOUBLE out (note the .0)
        System.out.println("Same numbers as doubles: " + Math.abs(237.0 - 250.0));
    }
}

ReadingTheDocs.main(null);

// %% [markdown]
// Compare the last two lines carefully: **same method name, same numbers, and the answers print as `13` and `13.0`.**
//
// Nothing about the values changed — only the *types* of what you passed in, which sent Java to a different documented entry with a different return type. The docs told you that would happen before you ran a single line. That's the whole point of this lesson.
//
// > You'll work through the `Math` class properly in Topic **1.11**. Here it's the example, not the subject.

// %% [markdown]
// ---
//
// # Practice: Reading the Supplier Catalog
//
// Four tasks, in order.
//
// ---
//
// ## Hack 1 — Attributes or behaviors?
//
// A `LoyaltyCard` class is being designed for the cafe. Sort each item into the right column and give a one-word reason (noun or verb). Double-click to edit.
//
// | Item | Attribute or behavior? | Noun or verb? |
// |---|---|---|
// | `customerName` | | |
// | `addStamp()` | | |
// | `stampCount` | | |
// | `redeemFreeDrink()` | | |
// | `isGoldMember` | | |
// | `getDiscountRate()` | | |
// | `dateIssued` | | |
// | `deactivate()` | | |
//
// <details>
// <summary><b>Check your answers</b></summary>
//
// | Item | Attribute or behavior? | Why |
// |---|---|---|
// | `customerName` | Attribute | Noun — data the card *knows* |
// | `addStamp()` | Behavior | Verb — something the card *does* |
// | `stampCount` | Attribute | Noun — a stored number |
// | `redeemFreeDrink()` | Behavior | Verb — an action |
// | `isGoldMember` | Attribute | A stored `boolean` fact |
// | `getDiscountRate()` | Behavior | Verb — it computes and returns something |
// | `dateIssued` | Attribute | Noun — stored data |
// | `deactivate()` | Behavior | Verb — an action |
//
// The parentheses are the dead giveaway every time: **behaviors have them, attributes don't.**
//
// `isGoldMember` is the one people second-guess. It sounds like a question, but it's a stored `true`/`false` value, not an action — and it has no parentheses.
// </details>

// %% [markdown]
// ---
//
// ## Hack 2 — The import audit
//
// For each class, name its package and say whether an `import` is required. Double-click to edit.
//
// | Class | Package | Import needed? |
// |---|---|---|
// | `String` | | |
// | `Scanner` | | |
// | `Math` | | |
// | `System` | | |
// | `Integer` | | |
// | `ArrayList` | | |
//
// Then answer: **a classmate's program fails with `cannot find symbol / symbol: class Scanner`. What single line fixes it, and where does it go?**
//
// **Your answer:**
//
// <details>
// <summary><b>Check your answers</b></summary>
//
// | Class | Package | Import needed? |
// |---|---|---|
// | `String` | `java.lang` | No |
// | `Scanner` | `java.util` | **Yes** |
// | `Math` | `java.lang` | No |
// | `System` | `java.lang` | No |
// | `Integer` | `java.lang` | No |
// | `ArrayList` | `java.util` | **Yes** |
//
// **The fix:** add `import java.util.Scanner;` at the very top of the file, **above** the class declaration. (`import java.util.*;` also works and brings in the whole package.)
//
// The pattern worth memorizing: everything in `java.lang` is free, everything else must be imported.
// </details>

// %% [markdown]
// ---
//
// ## Hack 3 — Code from documentation only
//
// Using **only** the `Math` documentation from Part 5 — no searching, no guessing — write code for these three cafe problems.
//
// | Entry | What it does |
// |---|---|
// | `static int abs(int x)` | Absolute value of `x` |
// | `static double abs(double x)` | Absolute value of `x` |
// | `static double pow(double base, double exponent)` | `base` raised to the `exponent` |
// | `static double sqrt(double x)` | Positive square root of `x` |
//
// **Problem 1.** The cafe's new sign is 3 ft by 4 ft. Compute the diagonal, which is the square root of (3² + 4²). Use `pow` **and** `sqrt`.
//
// **Problem 2.** The register expected `$250` but counted `$237`. Print how far off it was, as a positive number.
//
// **Problem 3.** Sales grow 10% each month, so after `n` months they're multiplied by `1.1` to the power of `n`. Print the multiplier after **6** months.

// %%
public class DocsOnly {
    public static void main(String[] args) {

        // TODO 1: diagonal of a 3 ft by 4 ft sign, using Math.pow and Math.sqrt

        // TODO 2: how far the register was off, using Math.abs

        // TODO 3: growth multiplier after 6 months at 10% per month, using Math.pow

    }
}

DocsOnly.main(null);

// %% [markdown]
// <details>
// <summary><b>One possible solution</b></summary>
//
// ```java
// public class DocsOnly {
//     public static void main(String[] args) {
//
//         double diagonal = Math.sqrt(Math.pow(3, 2) + Math.pow(4, 2));
//         System.out.println("Sign diagonal: " + diagonal + " ft");
//
//         int off = Math.abs(237 - 250);
//         System.out.println("Register off by: $" + off);
//
//         double multiplier = Math.pow(1.1, 6);
//         System.out.println("Growth after 6 months: " + multiplier);
//     }
// }
//
// DocsOnly.main(null);
// ```
//
// Output:
//
// ```
// Sign diagonal: 5.0 ft
// Register off by: $13
// Growth after 6 months: 1.7715610000000008
// ```
//
// Three things worth noticing:
//
// - **The diagonal is `5.0`, not `5`.** `sqrt` returns a `double`, exactly as documented, so the `.0` is there even though the answer is a whole number.
// - **`Math.abs(237 - 250)` returned `13`, not `13.0`.** Both arguments were `int` literals, so Java used `abs(int x)`, which returns an `int`.
// - **The growth multiplier ends in `...0008`.** That's roundoff error from 1.5 — `1.1` has no exact binary representation, and raising it to a power multiplies the tiny inaccuracy six times over.
// </details>

// %% [markdown]
// ---
//
// ## Hack 4 — Write your own API
//
// Design a `BobaMachine` class for the cafe. **Do not write any Java.** Write the documentation a *user* of your class would need.
//
// Requirements:
//
// - At least **4 attributes**, each with a type and a one-line description
// - At least **4 behaviors**, each written as a full API entry: return type, name, parameters, and a one-line description
// - At least one behavior must take a **parameter**
// - At least one behavior must **return** something other than `void`
//
// Use the Part 5 format: `returnType name(paramType paramName)`.
//
// **Double-click to fill in your design.**
//
// ### `BobaMachine`
//
// **Attributes**
//
// | Type | Name | Description |
// |---|---|---|
// | | | |
// | | | |
// | | | |
// | | | |
//
// **Behaviors**
//
// | Entry | Description |
// |---|---|
// | | |
// | | |
// | | |
// | | |
//
// **Finally, answer this:** name one thing your API deliberately *hides* from whoever uses it, and explain why hiding it is a good idea.
//
// **Your answer:**
//
// <details>
// <summary><b>One possible design</b></summary>
//
// **Attributes**
//
// | Type | Name | Description |
// |---|---|---|
// | `String` | `currentFlavor` | The flavor currently loaded in the machine |
// | `int` | `pearlScoopsLeft` | Scoops of tapioca remaining in the hopper |
// | `double` | `temperature` | Current brewing temperature in degrees F |
// | `boolean` | `isCleaning` | Whether a cleaning cycle is running |
//
// **Behaviors**
//
// | Entry | Description |
// |---|---|
// | `void loadFlavor(String flavor)` | Loads the given flavor into the machine |
// | `boolean dispenseDrink(int ounces)` | Dispenses a drink; returns `false` if supplies ran out |
// | `int getPearlScoopsLeft()` | Returns the number of scoops remaining |
// | `void startCleaningCycle()` | Begins a cleaning cycle |
//
// **What it hides:** the API says nothing about *how* the machine reaches the right temperature, how pearls are counted, or how long a cleaning cycle takes.
//
// **Why that's good:** the cafe can replace the machine with a faster model, and every program written against this API keeps working without a single change — because none of them ever depended on the hidden details. That's abstraction from Part 2, and it's the reason `Math.sqrt` has kept working across thirty years of Java versions.
// </details>

// %% [markdown]
// ---
//
// # Self-Check: AP-style questions
//
// **1.** Which best describes an API?
//
// &nbsp;&nbsp;(A) A program that translates Java source code into bytecode
// &nbsp;&nbsp;(B) Documentation describing what a class provides and how to use it
// &nbsp;&nbsp;(C) The internal source code that implements a class's methods
// &nbsp;&nbsp;(D) A collection of pre-written classes bundled with Java
//
// <details><summary>Answer</summary>
//
// **(B)**. An API describes the interface — what's available and how to call it. (C) is the implementation, which an API deliberately hides. (D) describes a **library**, which is related but not the same thing. (A) is the compiler.
// </details>
//
// ---
//
// **2.** Which of the following requires an `import` statement?
//
// &nbsp;&nbsp;(A) `String` &nbsp;&nbsp; (B) `Math` &nbsp;&nbsp; (C) `Scanner` &nbsp;&nbsp; (D) `System`
//
// <details><summary>Answer</summary>
//
// **(C)**. `Scanner` is in `java.util` and must be imported. The other three are all in `java.lang`, which every Java program imports automatically.
// </details>
//
// ---
//
// **3.** In a class describing a coffee machine, which is an **attribute** rather than a behavior?
//
// &nbsp;&nbsp;(A) `brewCoffee()` &nbsp;&nbsp; (B) `waterLevel` &nbsp;&nbsp; (C) `startCleaning()` &nbsp;&nbsp; (D) `dispense()`
//
// <details><summary>Answer</summary>
//
// **(B)**. `waterLevel` is data the machine *knows* — a noun, with no parentheses. The other three are actions the machine *does*.
// </details>
//
// ---
//
// **4.** Given the API entry `static double pow(double base, double exponent)`, what does `Math.pow(3, 2)` return?
//
// &nbsp;&nbsp;(A) `9` &nbsp;&nbsp; (B) `9.0` &nbsp;&nbsp; (C) `6.0` &nbsp;&nbsp; (D) `8.0`
//
// <details><summary>Answer</summary>
//
// **(B) `9.0`**. The documented return type is `double`, so the result carries a decimal even though 3² is a whole number. (A) is the right number with the wrong type — and reading the return type is exactly the skill being tested. (C) mistakes `pow` for multiplication.
// </details>
//
// ---
//
// **5.** A program fails to compile with `cannot find symbol / symbol: class ArrayList`. What is the most likely cause?
//
// &nbsp;&nbsp;(A) `ArrayList` does not exist in Java
// &nbsp;&nbsp;(B) The `import java.util.ArrayList;` statement is missing
// &nbsp;&nbsp;(C) The variable was never initialized
// &nbsp;&nbsp;(D) `ArrayList` can only be used inside a loop
//
// <details><summary>Answer</summary>
//
// **(B)**. "Cannot find symbol" on a **class name** means the compiler doesn't know where that class lives. `ArrayList` is in `java.util` and must be imported.
// </details>
//
// ---
//
// **6.** Why is it an advantage that the `Math` class's API does not describe how `sqrt` is implemented?
//
// &nbsp;&nbsp;(A) It makes the method run faster
// &nbsp;&nbsp;(B) It prevents programmers from calling the method incorrectly
// &nbsp;&nbsp;(C) The implementation can be improved without breaking programs that use it
// &nbsp;&nbsp;(D) It reduces the size of the compiled program
//
// <details><summary>Answer</summary>
//
// **(C)**. This is **abstraction**. Because no program depends on the hidden details, the internals can be rewritten or optimized and every existing program keeps working. Hiding the implementation is a design benefit, not a performance one.
// </details>
//
// ---
//
// **7.** Which of these is a **behavior** according to its documentation entry?
//
// &nbsp;&nbsp;(A) `Integer.MAX_VALUE`
// &nbsp;&nbsp;(B) `Integer.MIN_VALUE`
// &nbsp;&nbsp;(C) `static double random()`
// &nbsp;&nbsp;(D) None — they are all attributes
//
// <details><summary>Answer</summary>
//
// **(C)**. Even with empty parentheses, `random()` is something the class *does*. (A) and (B) are stored constants — attributes — and have no parentheses. Empty parentheses mean "needs no input," not "isn't a method."
// </details>
//
// ---
//
// **8.** A library and an API are related but different. Which statement is correct?
//
// &nbsp;&nbsp;(A) A library is the documentation; an API is the collection of classes
// &nbsp;&nbsp;(B) A library is the collection of classes; an API describes how to use them
// &nbsp;&nbsp;(C) They are two words for exactly the same thing
// &nbsp;&nbsp;(D) An API can only describe classes you wrote yourself
//
// <details><summary>Answer</summary>
//
// **(B)**. The library is the actual supply of code; the API is the catalog describing what's in it and how to order. (A) reverses them.
// </details>

// %% [markdown]
// ---
//
// # Closing time
//
// ### Vocabulary to know cold
//
// | Term | One-line definition |
// |---|---|
// | Library | A collection of pre-written classes available to your program |
// | API | Documentation describing what a class provides and how to use it |
// | Implementation | The hidden internal code that makes a class actually work |
// | Abstraction | Using something through its interface without knowing its internals |
// | Attribute | Data a class knows — a noun, no parentheses |
// | Behavior | Something a class does — a method, with parentheses |
// | Package | A named grouping of related classes, such as `java.util` |
// | `import` | A statement making a class from another package available |
// | `java.lang` | The package imported automatically into every Java program |
// | AP Java Quick Reference | The API subset provided to you during the AP exam |
//
// ### The five things that will show up on the exam
//
// 1. A **library** is the code; an **API** is the description of how to use it.
// 2. An API tells you **what**, never **how** — that's abstraction.
// 3. **Attributes** are nouns without parentheses; **behaviors** are verbs with them.
// 4. `java.lang` (`String`, `Math`, `System`, `Integer`) needs no import. Everything else does.
// 5. `cannot find symbol` on a class name means a **missing import**.
//
// ### Before you submit, check that you:
//
// - [ ] Ran every code cell top to bottom
// - [ ] Sorted all eight items in Hack 1 and justified each
// - [ ] Completed the Hack 2 import audit and named the exact fix line
// - [ ] Wrote Hack 3 using **only** the documentation, and got `5.0`, `$13`, and `1.7715610000000008`
// - [ ] Designed a full `BobaMachine` API in Hack 4, including what it hides and why
// - [ ] Attempted all eight self-check questions before revealing answers
//
// ### Next up
//
// **1.8 — Documentation with Comments.** You just spent a whole lesson reading other people's documentation. Next shift you flip sides and write your own — including the `/** */` Javadoc comments that *generate* API documentation automatically, plus preconditions and postconditions, which are how the AP exam itself describes what a method expects and promises.
//
// See you at the next shift 🧋
