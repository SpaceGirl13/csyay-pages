// %% [raw]
// ---
// layout: post
// title: "1.12 Objects: Instances of Classes"
// description: Boba Cafe Series, Lesson 12. The relationship between a class and an object, why multiple objects from the same class are independent, and how to declare reference-type variables.
// categories: [AP CSA, Unit 1]
// permalink: /csa/unit1/1-12
// toc: true
// comments: true
// ---

// %% [markdown]
// # 1.12 — Objects: Instances of Classes 🧋
//
// ### AP CSA · Unit 1: Using Objects and Methods
// **Boba Cafe Series · Lesson 12**
//
// ---
//
// > **Setup note:** every code cell runs on the **IJava kernel** (Java 17+). Check that the kernel picker says *Java*. Each cell declares a class and then calls it with `ClassName.main(null);`.
//
// > **Correcting last lesson's promise:** Lesson 1.11 closed by saying you'd "create your first real object" today. That undersold what you'd already done — you've been writing `new Scanner(...)` since Lesson 1.4, and every `"Taro Milk Tea"` you've ever typed in quotes has secretly been a `String` object. What's actually new today is the **vocabulary and the concept**: what a class and an object really are to each other, and how to declare a variable that stores one. The full mechanics of `new` and constructors — building an object step by step — is Topic **1.13**, next lesson.

// %% [markdown]
// ## You've been building objects the whole time
//
// Here's an uncomfortable question: in five words or fewer, what's the difference between a `String` and an `int`?
//
// You could probably answer *"one's a reference type"* — that's been sitting in your vocabulary since Lesson 1.2. But *why* is `String` a reference type, and what does "reference" actually refer to? What is `String` even a reference **to**?
//
// That's today's lesson. The cafe's recipe card for Taro Milk Tea is not a drink. It's a **blueprint** — instructions for making a drink. Every time a barista follows that card, a new, physical, separate cup of taro milk tea comes into existence. The recipe card doesn't run out. You can make a hundred cups from the same card, and spilling one doesn't affect the other ninety-nine.
//
// That relationship — one blueprint, many independent things built from it — is exactly the relationship between a **class** and an **object**.
//
// ### What you'll be able to do by the end
//
// | # | Objective | CED reference |
// |---|---|---|
// | 1 | Explain the relationship between a **class** and an **object** | 1.12.A |
// | 2 | Explain why two objects built from the same class are **independent** of each other | 1.12.A |
// | 3 | Declare a variable to store a **reference type** | 1.12.B |
// | 4 | Explain what a reference-type variable actually holds | 1.12.B |
// | 5 | Use `null` correctly, and distinguish it from an uninitialized variable | 1.12.B |

// %% [markdown]
// ---
//
// ## Part 1 — Class as blueprint, object as instance
//
// > **A class is a blueprint.** It describes what something is made of and what it can do, without being an actual "something" itself.
// > **An object is an instance of a class** — one concrete thing built following that blueprint.
//
// Nobody drinks a recipe card. Nobody drinks `String` either. `String` describes *what a string of text is and does* — that it holds characters, that it has a `length()`, that it can be compared. Every time you write `"Taro Milk Tea"`, Java builds an actual `String` **object**: one concrete, particular piece of text living in memory, built according to the `String` blueprint.
//
// ```
//              CLASS (the blueprint)                 OBJECT (an instance)
//     ┌───────────────────────────────┐      ┌──────────────────────────┐
//     │  String                       │      │  "Taro Milk Tea"         │
//     │  -- describes: holds text     │─────►│  one particular String,  │
//     │  -- describes: has length()   │      │  built from the blueprint│
//     └───────────────────────────────┘      └──────────────────────────┘
// ```
//
// You don't only build one object per class, either. Just like one recipe card produces every cup of taro milk tea the cafe ever serves, one `String` class produces every piece of text every Java program on Earth has ever created.

// %%
public class ClassVsObject {
    public static void main(String[] args) {
        // Three SEPARATE String objects, all built from the SAME String class/blueprint.
        String drink1 = "Taro Milk Tea";
        String drink2 = "Matcha Latte";
        String drink3 = "Thai Tea";

        System.out.println(drink1);
        System.out.println(drink2);
        System.out.println(drink3);

        System.out.println();
        System.out.println("Three different objects. One shared blueprint: the String class.");
    }
}

ClassVsObject.main(null);

// %% [markdown]
// ---
//
// ## Part 2 — Objects are independent
//
// This is the property that actually makes objects useful: **two objects built from the same class don't affect each other.** Changing one never touches the other, even though they were stamped from identical instructions.
//
// `Scanner` makes this easy to see, because a `Scanner` object keeps track of **where it currently is** in its input — and that position belongs to one specific `Scanner`, not to the `Scanner` class in general.

// %%
import java.util.Scanner;

public class IndependentObjects {
    public static void main(String[] args) {
        // Two SEPARATE Scanner objects, each with its OWN position in its OWN input.
        Scanner scanA = new Scanner("Taro Milk Tea");
        Scanner scanB = new Scanner("Matcha Latte");

        System.out.println("scanA reads: " + scanA.next());   // "Taro"
        System.out.println("scanB reads: " + scanB.next());   // "Matcha"

        // Advancing scanA does NOT move scanB. They are independent objects.
        System.out.println("scanA reads next: " + scanA.next());          // "Milk"
        System.out.println("scanB is unaffected, still reads: " + scanB.next());   // "Latte"
    }
}

IndependentObjects.main(null);

// %% [markdown]
// `scanA` reading further into its own input had zero effect on `scanB`. Both objects came from the identical `Scanner` blueprint, and yet each one tracks its own separate position — because each object gets its **own copy** of whatever data the class describes. This is the recipe-card idea made concrete: one card, unlimited independent cups, none of them sharing tea.

// %% [markdown]
// ---
//
// ## Part 3 — Declaring a reference-type variable
//
// Back in Lesson 1.2, you saw this exact picture:
//
// ```
//   PRIMITIVE                          REFERENCE
//   int cupsSold = 12;                 String name = "Riley";
//
//   cupsSold                           name
//  ┌──────────┐                       ┌──────────┐        ┌───────────┐
//  │    12    │  <- the value          │  0x4a2f  │ ─────► │  "Riley"  │
//  └──────────┘     lives right here   └──────────┘        └───────────┘
//                                       an address          the actual
//                                       to somewhere         object
// ```
//
// Now you can say precisely what that arrow means: **a reference-type variable doesn't hold the object itself — it holds a reference (an address) pointing to where the object actually lives.** The variable `name` is not the text `"Riley"`. It's a pointer that says "the actual object is over there."
//
// The **declaration syntax is identical** to declaring a primitive from Lesson 1.2 — `Type variableName;` — the difference is entirely in what gets stored once you assign something.

// %%
import java.util.Scanner;

public class DeclaringReferences {
    public static void main(String[] args) {
        // Declaration syntax: Type variableName; -- same shape as a primitive from 1.2
        String customerName;
        Scanner orderScanner;

        // Assignment gives each variable a REFERENCE to a real object
        customerName = "Riley";
        orderScanner = new Scanner("2 Taro Milk Tea");

        System.out.println("customerName refers to: " + customerName);
        System.out.println("orderScanner's first token: " + orderScanner.next());
    }
}

DeclaringReferences.main(null);

// %% [markdown]
// That worked exactly like declaring an `int` and assigning it later (Lesson 1.4) — declare first, assign after, on separate lines. The only thing that changed is *what kind of thing* gets stored: an `int` variable stores a value directly; `customerName` and `orderScanner` store references to objects sitting elsewhere.
//
// ### Reading before assigning still fails, for the same reason as 1.4
//
// **Heads up: the next cell is supposed to fail.**

// %%
public class TooSoonReference {
    public static void main(String[] args) {
        String flavor;                          // declared, but no object assigned yet
        System.out.println("Flavor: " + flavor); // trying to read an empty reference
    }
}

TooSoonReference.main(null);

// %% [markdown]
// `variable flavor might not have been initialized` — the exact same compile-time protection from Lesson 1.4, now applied to a reference type instead of a primitive. Java refuses to let you read a variable that has never been given anything to refer to.

// %% [markdown]
// ---
//
// ## Part 4 — `null`: a reference to nothing
//
// Primitives have no way to say "I have no value" — an `int` is always some number. Reference types are different: they can deliberately point at **nothing at all**.
//
// > **`null` is a literal meaning "this reference variable does not currently point to any object."**
//
// This is different from the uninitialized error you just saw. Assigning `null` is a real, legal assignment — it just assigns "nothing" on purpose, instead of leaving the variable empty and unassigned.

// %%
import java.util.Scanner;

public class NullReferences {
    public static void main(String[] args) {
        String flavor = null;      // explicitly refers to NO object -- this is legal
        Scanner backup = null;     // same idea for any reference type

        System.out.println("flavor is: " + flavor);
        System.out.println("backup is: " + backup);

        flavor = "Taro";           // now it refers to a real object
        System.out.println("flavor is now: " + flavor);
    }
}

NullReferences.main(null);

// %% [markdown]
// Printing a `null` reference doesn't crash — it prints the word `null`, harmlessly. That's worth remembering, because it's about to matter: `null` is genuinely useful for representing "no drink selected yet" or "no customer assigned to this order," in a way a primitive simply cannot express.
//
// > **A preview, not today's problem:** *calling a method* on a `null` reference — like `flavor.length()` when `flavor` is `null` — is a different story entirely, and it crashes. That's `NullPointerException`, and it's the formal subject of Topic **1.14**. Today, just know that `null` itself is a legal, harmless value to store and print.
//
// ### The full picture: declared, uninitialized, null, and assigned
//
// | State | Example | Can you print it? |
// |---|---|---|
// | Declared, never assigned | `String s;` | **No** — compile-time error |
// | Assigned `null` | `String s = null;` | **Yes** — prints `null` |
// | Assigned a real object | `String s = "Taro";` | **Yes** — prints `Taro` |

// %% [markdown]
// ---
//
// ## Part 5 — Putting it together: the order queue
//
// One more example, using everything from this lesson. Three separate `Scanner` objects simulate three separate customers' orders arriving — same class, same code building each one, completely independent results.

// %%
import java.util.Scanner;

public class OrderQueue {
    public static void main(String[] args) {
        // Three objects, one class. Each is a completely independent order.
        Scanner order1 = new Scanner("Riley 2 TaroMilkTea");
        Scanner order2 = new Scanner("Jordan 1 MatchaLatte");
        Scanner order3 = new Scanner("Sam 3 ThaiTea");

        printOrder(order1);
        printOrder(order2);
        printOrder(order3);
    }

    public static void printOrder(Scanner order) {
        String name     = order.next();
        int    quantity = order.nextInt();
        String drink    = order.next();
        System.out.println(name + " ordered " + quantity + "x " + drink);
    }
}

OrderQueue.main(null);

// %% [markdown]
// `printOrder` is a single method that gets handed a **different object** each time it's called (this is a method parameter of a reference type — the same idea as any other parameter from Lesson 1.9, just holding a reference this time instead of a primitive). Nothing about `order1` leaked into `order2` or `order3`. Three blueprints, three independent objects, three independent results — the entire lesson in one program.

// %% [markdown]
// ---
//
// # Practice: Stocking the Object Shelf
//
// Four tasks, in order.
//
// ---
//
// ## Hack 1 — Class or object?
//
// For each item, say whether it describes a **class** (a blueprint) or an **object** (a specific instance). Double-click to edit.
//
// | Item | Class or object? |
// |---|---|
// | `String` | |
// | `"Brown Sugar Milk Tea"` | |
// | `Scanner` | |
// | `new Scanner("Taro 3")` | |
// | The general idea of "a cup of boba" | |
// | The specific cup sitting on the counter right now | |
//
// <details>
// <summary><b>Check your answers</b></summary>
//
// | Item | Class or object? |
// |---|---|
// | `String` | Class — the blueprint for text |
// | `"Brown Sugar Milk Tea"` | Object — one specific `String` built from that blueprint |
// | `Scanner` | Class — the blueprint for reading input |
// | `new Scanner("Taro 3")` | Object — one specific `Scanner`, built and ready to use |
// | "a cup of boba" in general | Class-like — a description, not an actual drink |
// | The specific cup on the counter | Object — one real, physical instance |
//
// The pattern: a class is a **description**. An object is a **thing** that description was used to build.
// </details>

// %% [markdown]
// ---
//
// ## Hack 2 — Predict the independence
//
// Three `Scanner` objects are built from three different strings. Predict what each `.next()` call returns, **in the order the calls happen** — not the order the objects were declared. Fill in your predictions before running.
//
// ```java
// Scanner s1 = new Scanner("Alpha Beta");
// Scanner s2 = new Scanner("One Two");
//
// System.out.println(s1.next());   // call 1
// System.out.println(s2.next());   // call 2
// System.out.println(s1.next());   // call 3
// System.out.println(s2.next());   // call 4
// ```
//
// | Call | Your prediction |
// |---|---|
// | 1 | |
// | 2 | |
// | 3 | |
// | 4 | |

// %%
import java.util.Scanner;

public class PredictIndependence {
    public static void main(String[] args) {
        Scanner s1 = new Scanner("Alpha Beta");
        Scanner s2 = new Scanner("One Two");

        System.out.println("1. " + s1.next());
        System.out.println("2. " + s2.next());
        System.out.println("3. " + s1.next());
        System.out.println("4. " + s2.next());
    }
}

PredictIndependence.main(null);

// %% [markdown]
// <details>
// <summary><b>Check your answers</b></summary>
//
// `Alpha`, `One`, `Beta`, `Two` — in that order.
//
// Each `Scanner` remembers its own position independently. Reading from `s2` in between two reads of `s1` doesn't cost `s1` anything or skip it forward — `s1` picks up exactly where **it** left off, regardless of what `s2` was doing in the meantime.
// </details>

// %% [markdown]
// ---
//
// ## Hack 3 — Fix the broken declarations
//
// The cell below has **two** bugs related to this lesson. Run it, fix both, then fill in the report.

// %%
import java.util.Scanner;

public class BrokenDeclarations {
    public static void main(String[] args) {
        String customerName;
        System.out.println("Welcome, " + customerName);

        Scanner orderScan = new Scanner("Taro 2");
        String drink = orderScan.next();
        int quantity = orderScan.nextInt();

        String backupNote = "";
        backupNote = nul;

        System.out.println(drink + " x" + quantity);
        System.out.println("Backup note: " + backupNote);
    }
}

BrokenDeclarations.main(null);

// %% [markdown]
// **Your bug report** (double-click to edit):
//
// | Bug | What was wrong | Your fix |
// |---|---|---|
// | 1 | | |
// | 2 | | |
//
// <details>
// <summary><b>Check your answers</b></summary>
//
// **Bug 1 — reading a reference variable before it's assigned.** `customerName` is declared but never given an object, then it's used inside a `println`. Fix by assigning it first:
//
// ```java
// String customerName = "Riley";
// ```
//
// **Bug 2 — `nul` instead of `null`.** This is a typo, not a real keyword, so Java reports "cannot find symbol" — it looks like a variable reference to something that was never declared. Fix the spelling:
//
// ```java
// backupNote = null;
// ```
//
// (If you only found one bug: look again at the `nul` line — a one-character typo away from a real keyword is exactly the kind of error that's easy to skim past.)
// </details>

// %% [markdown]
// ---
//
// ## Hack 4 — Build three independent readers
//
// Write a program that:
//
// 1. Declares **three** `Scanner` variables, each reading from a **different** String of your choosing (each string should contain at least two words).
// 2. Calls `.next()` on each scanner exactly **twice**, in an order that is **not** simply "finish scanner 1, then scanner 2, then scanner 3" — interleave the calls.
// 3. Prints every result with a label saying which scanner it came from.
// 4. In a comment at the bottom, explain in one sentence why interleaving the calls doesn't cause any scanner to "lose its place."

// %%
import java.util.Scanner;

public class MyThreeReaders {
    public static void main(String[] args) {

        // TODO 1: declare three Scanner variables reading from three different strings

        // TODO 2: interleave six total .next() calls across the three scanners, each labeled

        // TODO 3: one-sentence comment explaining why interleaving is safe

    }
}

MyThreeReaders.main(null);

// %% [markdown]
// <details>
// <summary><b>One possible solution</b></summary>
//
// ```java
// import java.util.Scanner;
//
// public class MyThreeReaders {
//     public static void main(String[] args) {
//         Scanner drink   = new Scanner("Taro MilkTea");
//         Scanner topping = new Scanner("Extra Pearls");
//         Scanner size    = new Scanner("Large Cup");
//
//         System.out.println("drink:   " + drink.next());
//         System.out.println("topping: " + topping.next());
//         System.out.println("size:    " + size.next());
//         System.out.println("drink:   " + drink.next());
//         System.out.println("size:    " + size.next());
//         System.out.println("topping: " + topping.next());
//
//         // Each Scanner is a separate object with its own independent position in its
//         // own input, so reading from one never affects where the others currently are.
//     }
// }
//
// MyThreeReaders.main(null);
// ```
//
// Output:
//
// ```
// drink:   Taro
// topping: Extra
// size:    Large
// drink:   MilkTea
// size:    Cup
// topping: Pearls
// ```
//
// Notice `drink` correctly picked up `MilkTea` on its second call even though two calls to *other* scanners happened first — exactly the independence from Part 2.
// </details>

// %% [markdown]
// ---
//
// # Self-Check: AP-style questions
//
// **1.** Which best describes the relationship between a class and an object?
//
// &nbsp;&nbsp;(A) A class is one specific object; an object is a category of classes
// &nbsp;&nbsp;(B) A class is a blueprint describing behavior and data; an object is a specific instance built from it
// &nbsp;&nbsp;(C) They are two names for the same thing
// &nbsp;&nbsp;(D) A class can only ever produce one object
//
// <details><summary>Answer</summary>
//
// **(B)**. A class describes what something is and does; an object is one concrete instance built according to that description. (D) is wrong — a single class can produce unlimited independent objects.
// </details>
//
// ---
//
// **2.** Two `Scanner` objects, `a` and `b`, are created from different input strings. After calling `a.next()` three times, what is true about `b`'s position in its own input?
//
// &nbsp;&nbsp;(A) `b` has also advanced three tokens
// &nbsp;&nbsp;(B) `b` is completely unaffected, since each object tracks its own state independently
// &nbsp;&nbsp;(C) `b` throws an exception the next time it's used
// &nbsp;&nbsp;(D) `b` and `a` now refer to the same object
//
// <details><summary>Answer</summary>
//
// **(B)**. Objects built from the same class are independent. Changing one object's internal state never affects a different object, even one built from the identical class.
// </details>
//
// ---
//
// **3.** What does a reference-type variable actually store?
//
// &nbsp;&nbsp;(A) A copy of the entire object's data
// &nbsp;&nbsp;(B) A reference (an address) pointing to where the object lives
// &nbsp;&nbsp;(C) The class's source code
// &nbsp;&nbsp;(D) Nothing — reference types don't need to store anything
//
// <details><summary>Answer</summary>
//
// **(B)**. A reference-type variable holds an address pointing to the object, not the object's data directly. This is the distinction first introduced in Lesson 1.2, between primitive and reference storage.
// </details>
//
// ---
//
// **4.** What happens when this code runs?
//
// ```java
// String drink;
// System.out.println(drink);
// ```
//
// &nbsp;&nbsp;(A) It prints an empty string
// &nbsp;&nbsp;(B) It prints `null`
// &nbsp;&nbsp;(C) A compile-time error, because `drink` might not have been initialized
// &nbsp;&nbsp;(D) A run-time error when the `println` executes
//
// <details><summary>Answer</summary>
//
// **(C)**. Declaring `drink` doesn't assign it anything. Reading it before any assignment — including before an explicit `null` — is a compile-time error, identical in spirit to reading an uninitialized primitive from Lesson 1.4.
// </details>
//
// ---
//
// **5.** What happens when this code runs?
//
// ```java
// String drink = null;
// System.out.println(drink);
// ```
//
// &nbsp;&nbsp;(A) A compile-time error, since `drink` was never assigned a real object
// &nbsp;&nbsp;(B) A run-time crash
// &nbsp;&nbsp;(C) It prints the word `null`
// &nbsp;&nbsp;(D) It prints an empty line
//
// <details><summary>Answer</summary>
//
// **(C)**. Assigning `null` is a legal, explicit assignment — it satisfies the "must be initialized" rule, and `null` is a value Java is happy to print. It's calling a *method* on a `null` reference that causes a crash, not printing it — and that's next lesson's topic.
// </details>
//
// ---
//
// **6.** Which of the following is a valid declaration of a reference-type variable, using the same syntax pattern as declaring a primitive?
//
// &nbsp;&nbsp;(A) `String name;`
// &nbsp;&nbsp;(B) `new String name;`
// &nbsp;&nbsp;(C) `reference String name;`
// &nbsp;&nbsp;(D) `String new name;`
//
// <details><summary>Answer</summary>
//
// **(A)**. Declaration follows the exact same `Type variableName;` shape used for primitives since Lesson 1.2 — `String` is simply the type. The others aren't valid Java syntax.
// </details>
//
// ---
//
// **7.** A method parameter has type `Scanner`. What is passed into the method when it's called?
//
// &nbsp;&nbsp;(A) A brand-new, separate copy of the entire `Scanner` object
// &nbsp;&nbsp;(B) A reference to the same `Scanner` object the caller has
// &nbsp;&nbsp;(C) Nothing — `Scanner` cannot be passed as a parameter
// &nbsp;&nbsp;(D) Only the `Scanner` class's name, as a `String`
//
// <details><summary>Answer</summary>
//
// **(B)**. Just like any reference-type variable, a `Scanner` parameter holds a reference to the object. The method receives a way to reach the same object the caller already had — not a fresh independent copy of it.
// </details>

// %% [markdown]
// ---
//
// # Closing time
//
// ### Vocabulary to know cold
//
// | Term | One-line definition |
// |---|---|
// | Class | A blueprint describing what objects of that type know and can do |
// | Object | A specific instance built according to a class's blueprint |
// | Instance | Another word for a specific object built from a class |
// | Reference-type variable | A variable that stores an address pointing to an object, not the object itself |
// | `null` | A literal meaning "this reference points to no object" |
//
// ### The five things that will show up on the exam
//
// 1. A **class** is a blueprint; an **object** is one instance built from it.
// 2. Objects from the **same class** are still **independent** of each other.
// 3. A reference-type variable declares with the same syntax as a primitive: `Type name;`.
// 4. Reading a reference variable before it's assigned is a **compile-time error** — same rule as 1.4, for primitives.
// 5. `null` is a **legal, explicit value** — different from being uninitialized, and safe to print.
//
// ### Before you submit, check that you:
//
// - [ ] Ran every code cell, including the one that fails on purpose
// - [ ] Sorted all six items in Hack 1 as class or object
// - [ ] Predicted the Hack 2 interleaved output **before** running it
// - [ ] Fixed both bugs in Hack 3
// - [ ] Built three independent, interleaved `Scanner` readers in Hack 4
// - [ ] Attempted all seven self-check questions before revealing answers
//
// ### Next up
//
// **1.13 — Object Creation and Storage.** You now know what a class and an object are to each other, and how to declare a variable that can hold one. Next shift is the mechanics: what `new` actually does step by step, what a **constructor** is, and where in memory an object actually lives once it's built.
//
// See you at the next shift 🧋
