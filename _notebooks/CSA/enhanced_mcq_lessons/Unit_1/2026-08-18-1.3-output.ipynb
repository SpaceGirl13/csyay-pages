// %% [raw]
// ---
// layout: post
// title: 1.3 Expressions and Output
// description: Boba Cafe Series, Lesson 3. print vs println, string literals and escape sequences, concatenation, arithmetic operators, integer division, remainder, and operator precedence.
// categories: [AP CSA, Unit 1]
// permalink: /csa/unit1/1-3
// toc: true
// comments: true
// ---

// %% [markdown]
// # 1.3 — Expressions and Output 🧋
//
// ### AP CSA · Unit 1: Using Objects and Methods
// **Boba Cafe Series · Lesson 3**
//
// ---
//
// > **Setup note:** every code cell runs on the **IJava kernel** (Java 17+). Check that the kernel picker says *Java*. Each cell declares a class and then calls it with `ClassName.main(null);`.

// %% [markdown]
// ## The receipt printer is lying
//
// You get to Byte-Sized Boba and the manager is holding a receipt.
//
// > "A customer bought two drinks at $6 each with a $2 delivery fee. The receipt says the subtotal is **$122**. Then it says each of the two of them gets **12 ounces** out of a 25-ounce order. Neither number is right and the program didn't crash. Figure it out."
//
// Both bugs in that story are **logic errors** — the exact kind you met in 1.1, where Java does precisely what you wrote and hands you a wrong answer with a straight face. By the end of this notebook you'll know why both happened, and you'll be able to look at any Java expression and predict its output before running it.
//
// That last skill is the whole point. "What is printed by the following code segment?" is one of the most common question stems on the AP exam.
//
// ### What you'll be able to do by the end
//
// | # | Objective | CED reference |
// |---|---|---|
// | 1 | Produce output with `System.out.print` and `System.out.println` and predict the display | 1.3.A |
// | 2 | Use string literals and escape sequences (`\"`, `\\`, `\n`) | 1.3.B |
// | 3 | Combine text and values with the `+` concatenation operator | 1.3.B |
// | 4 | Evaluate arithmetic expressions using `+`, `-`, `*`, `/`, `%` | 1.3.C |
// | 5 | Predict the result of **integer division** and mixed `int`/`double` arithmetic | 1.3.C |
// | 6 | Apply operator precedence and use parentheses to control it | 1.3.C |

// %% [markdown]
// ---
//
// ## Part 1 — `print` vs `println`
//
// You've been using `System.out.println` since Lesson 1. It has a sibling.
//
// | Statement | What it does |
// |---|---|
// | `System.out.print(x)` | Displays `x` and **leaves the cursor where it is** |
// | `System.out.println(x)` | Displays `x`, then **moves the cursor to a new line** |
// | `System.out.println()` | Displays nothing, just moves to a new line — a blank line |
//
// Think of the cursor as the tip of a marker on the cafe's chalkboard menu. `print` writes and leaves the marker where it stopped. `println` writes and then drops down to start a fresh line.
//
// Run this and compare the two halves of the output.

// %%
public class PrintVsPrintln {
    public static void main(String[] args) {
        // print -- everything lands on ONE line
        System.out.print("Taro");
        System.out.print("Matcha");
        System.out.print("Thai");

        System.out.println();          // empty println = just move to a new line

        // println -- each one starts a fresh line
        System.out.println("Taro");
        System.out.println("Matcha");
        System.out.println("Thai");
    }
}

PrintVsPrintln.main(null);

// %% [markdown]
// Notice `TaroMatchaThai` ran together with no spaces. `print` adds **nothing** — not a space, not a line break. If you want a space, you have to put one there yourself.
//
// This matters on the exam. When a question shows a mix of `print` and `println` and asks what's displayed, you have to track the cursor line by line.

// %% [markdown]
// ---
//
// ## Part 2 — String literals and escape sequences
//
// > **Definition:** A **string literal** is fixed text written inside double quotation marks, like `"Taro Milk Tea"`.
//
// Simple enough — until you need to print a character that has a special meaning in Java. How do you print a **double quote** when double quotes are what mark the beginning and end of your text?
//
// That's what **escape sequences** are for. A backslash tells Java "the next character is data, not punctuation."
//
// | Escape sequence | Prints | Use it for |
// |---|---|---|
// | `\"` | `"` | A quotation mark inside a string |
// | `\\` | `\` | A single backslash (file paths, mostly) |
// | `\n` | *new line* | Breaking one string across multiple lines |
//
// Those three are the ones named in the CED. A fourth, `\t`, inserts a tab and is handy for lining up columns — you'll see it below.
//
// The important mental shift: `\n` is **one character**, not two. The backslash isn't printed; it's an instruction to the compiler.

// %%
public class MenuBoard {
    public static void main(String[] args) {
        System.out.println("Today's special: \"Brown Sugar Deluxe\"");   // \" prints a quote
        System.out.println("Recipe saved to C:\\cafe\\menu.txt");          // \\ prints one backslash
        System.out.println("Hot drinks\nCold drinks\nSmoothies");        // \n breaks the line

        System.out.println();

        System.out.println("Item\t\tPrice");                             // \t is a tab
        System.out.println("Taro\t\t$5.75");
        System.out.println("Matcha\t\t$6.00");
    }
}

MenuBoard.main(null);

// %% [markdown]
// Look at the second line of output carefully: you typed **four** backslashes in the source and got **two** in the display. Each `\\` in your code produces exactly one backslash on screen.
//
// And notice the third statement was a *single* `println` that produced *three* lines of output. `\n` gives you line breaks without extra statements.

// %% [markdown]
// ---
//
// ## Part 3 — Concatenation, and the trap hiding inside it
//
// The `+` operator does two completely different jobs depending on what's on either side of it:
//
// - **Number `+` number** → arithmetic. `5 + 3` gives `8`.
// - **String `+` anything** → **concatenation**. The other value is converted to text and glued on.
//
// `"Cups: " + 3` produces the text `Cups: 3`. The `3` stopped being a number the moment it touched a String.

// %%
public class Concatenation {
    public static void main(String[] args) {
        String first  = "Brown Sugar";
        String second = "Milk Tea";

        System.out.println(first + " " + second);        // String + String
        System.out.println("Cups ordered: " + 3);        // String + int
        System.out.println("Price: $" + 5.75);           // String + double
        System.out.println("In stock? " + true);         // String + boolean
    }
}

Concatenation.main(null);

// %% [markdown]
// ### The trap: `+` evaluates left to right
//
// Here's the manager's `$122` bug. Java reads a chain of `+` operators **left to right**, one pair at a time. Once a String enters the chain, *everything after it* becomes concatenation.
//
// Trace `"Total: " + 5 + 3` the way Java does:
//
// ```
//   "Total: " + 5 + 3
//    \_______ ______/
//            v
//        "Total: 5"      <- String + int gives a String
//                  + 3
//    \_____________ ___/
//                  v
//        "Total: 53"     <- String + int gives a String again
// ```
//
// The `5` and the `3` never met each other. Now run it.

// %%
public class ConcatTrap {
    public static void main(String[] args) {
        System.out.println("Total: " + 5 + 3);       // left to right: "Total: 5" then "Total: 53"
        System.out.println("Total: " + (5 + 3));     // parentheses force the math first
        System.out.println(5 + 3 + " drinks");       // math happens BEFORE the String appears
        System.out.println("Order " + 1 + 2 + 3);
    }
}

ConcatTrap.main(null);

// %% [markdown]
// Compare lines 1 and 3. Same operator, same values, opposite results — because in line 3 the two ints meet **before** the String joins the chain, so `+` is still doing arithmetic.
//
// **The rule to memorize:** if you want math to happen inside a printed message, wrap it in parentheses. Every time.
//
// ```java
// System.out.println("Total: " + (quantity * price));   // do this
// ```

// %% [markdown]
// ---
//
// ## Part 4 — Arithmetic operators
//
// Java gives you five arithmetic operators.
//
// | Operator | Name | Example | Result |
// |---|---|---|---|
// | `+` | Addition | `4 + 3` | `7` |
// | `-` | Subtraction | `4 - 3` | `1` |
// | `*` | Multiplication | `4 * 3` | `12` |
// | `/` | Division | `12 / 3` | `4` |
// | `%` | Remainder ("mod") | `13 % 4` | `1` |
//
// The first four you know from math class. `%` is probably new: it gives you **what's left over** after division. `13 % 4` is `1` because 4 goes into 13 three times with 1 left over.
//
// `%` is far more useful than it looks. It answers questions like "is this number even?" (`n % 2 == 0`), "which leftovers didn't fit?", and "every 5th customer gets a free drink" (`n % 5 == 0`).

// %%
public class BasicMath {
    public static void main(String[] args) {
        int scoopsPerCup = 3;
        int cups         = 4;

        System.out.println("Scoops needed:    " + (scoopsPerCup * cups));
        System.out.println("One more cup:     " + (cups + 1));
        System.out.println("One cancellation: " + (cups - 1));
        System.out.println("Even split of 12: " + (12 / 4));
        System.out.println("Leftover of 13:   " + (13 % 4));
    }
}

BasicMath.main(null);

// %% [markdown]
// ---
//
// ## Part 5 — Integer division: the biggest trap in Unit 1
//
// Read this rule twice, because the AP exam tests it constantly:
//
// > **When both operands are `int`, the result is an `int`.** Java throws away the fractional part — it does **not** round.
//
// So `7 / 2` is `3`. Not `3.5`, and not `4`. The `.5` is discarded, not rounded up.
//
// This is where the manager's second bug came from: 25 ounces split between 2 cups was computed as `25 / 2`, which is `12`, and the missing half-ounce vanished silently.
//
// ### But it isn't a bug — it's a tool
//
// Integer division and `%` are a matched pair. Together they answer "how many whole groups, and how many left over?"
//
// The cafe has 20 cups to pack into trays that hold 6 each:

// %%
public class TrayPacking {
    public static void main(String[] args) {
        int cups        = 20;
        int cupsPerTray = 6;

        int fullTrays = cups / cupsPerTray;    // how many COMPLETE trays
        int leftover  = cups % cupsPerTray;    // how many cups don't fill a tray

        System.out.println("Cups to pack:   " + cups);
        System.out.println("Full trays:     " + fullTrays);
        System.out.println("Cups left over: " + leftover);
        System.out.println("Check: " + fullTrays + " x " + cupsPerTray + " + " + leftover + " = " + cups);
    }
}

TrayPacking.main(null);

// %% [markdown]
// ### Rescuing the fraction: mix in a `double`
//
// The other half of the rule:
//
// > **If at least one operand is a `double`, the result is a `double`.**
//
// So you only need *one* side of the division to be a `double` to keep the decimal. Writing `2.0` instead of `2` is enough.

// %%
public class SplitTheDrink {
    public static void main(String[] args) {
        int totalOunces = 25;
        int cups        = 2;

        System.out.println("int / int:        " + (totalOunces / cups));    // 12  -- the .5 is gone
        System.out.println("int / double:     " + (totalOunces / 2.0));     // 12.5
        System.out.println("double / int:     " + (25.0 / cups));           // 12.5
        System.out.println("Remainder:        " + (totalOunces % cups));    // 1
    }
}

SplitTheDrink.main(null);

// %% [markdown]
// One operand being a `double` was enough to change the entire result. That's the fix for the receipt printer.
//
// > Deliberately converting between types — writing `(double) totalOunces / cups` — is called **casting**, and it's Topic **1.5**. For now, the `2.0` trick is enough.

// %% [markdown]
// ### Dividing by zero
//
// Back in 1.1 you saw an `ArithmeticException` from dividing an `int` by zero. Now you know exactly which operator caused it.
//
// **Heads up: the next cell is supposed to fail.**

// %%
public class NoFriends {
    public static void main(String[] args) {
        int totalOunces = 16;
        int friends     = 0;

        System.out.println("Pouring the drinks...");
        System.out.println("Each person gets: " + (totalOunces / friends));
        System.out.println("This line never runs.");
    }
}

NoFriends.main(null);

// %% [markdown]
// The first line printed, then the program crashed — the fingerprint of a **run-time error**.
//
// Here's something genuinely surprising, though: `double` division by zero does *not* crash.

// %%
public class DoubleDivide {
    public static void main(String[] args) {
        System.out.println("16.0 / 0 = " + (16.0 / 0));    // no crash
        System.out.println("0.0 / 0  = " + (0.0 / 0));     // "not a number"
        System.out.println("Program survived.");
    }
}

DoubleDivide.main(null);

// %% [markdown]
// `Infinity` and `NaN` ("not a number") are real `double` values Java uses instead of crashing. You won't be asked to compute with them in 1.3 — this is here so the contrast sticks: **`int` division by zero crashes, `double` division by zero doesn't.** You'll revisit precision limits in 1.5.

// %% [markdown]
// ---
//
// ## Part 6 — Operator precedence
//
// When one expression has several operators, Java doesn't just work left to right. It follows an order.
//
// | Priority | Operators | Direction |
// |---|---|---|
// | 1 (highest) | `( )` parentheses | innermost first |
// | 2 | `*` `/` `%` | left to right |
// | 3 (lowest) | `+` `-` | left to right |
//
// Two things students get wrong:
//
// 1. **`%` has the same priority as `*` and `/`** — not lower. `10 + 7 % 3` is `10 + 1`, which is `11`.
// 2. **Same-priority operators go left to right.** `20 / 5 * 2` is `(20 / 5) * 2 = 8`, not `20 / (5 * 2) = 2`.
//
// Parentheses beat everything, and they cost nothing. When in doubt, add them — clear code is worth more than clever code.

// %%
public class PrecedencePuzzle {
    public static void main(String[] args) {
        double price    = 5.00;
        int    quantity = 3;

        System.out.println("price * quantity + 2   = " + (price * quantity + 2));    // * first
        System.out.println("price * (quantity + 2) = " + (price * (quantity + 2)));  // parens first

        System.out.println("10 - 2 * 3   = " + (10 - 2 * 3));      // * before -
        System.out.println("20 / 5 * 2   = " + (20 / 5 * 2));      // left to right
        System.out.println("10 + 7 % 3   = " + (10 + 7 % 3));      // % before +
        System.out.println("(10 + 7) % 3 = " + ((10 + 7) % 3));    // parens change everything
    }
}

PrecedencePuzzle.main(null);

// %% [markdown]
// ---
//
// ## Part 7 — The exam skill: tracing output
//
// "What is printed by the following code segment?" Here's the method that works every time.
//
// **Work one statement at a time. For each one: evaluate the expression fully, then decide whether the cursor moves.**
//
// Trace this by hand before you run it:
//
// ```java
// int a = 7;
// int b = 2;
// System.out.println("A: " + a / b);
// System.out.println("B: " + a % b);
// System.out.println("C: " + (a + b) / 3);
// System.out.print("D: ");
// System.out.print(a * b);
// System.out.println(" done");
// ```
//
// <details>
// <summary><b>Worked trace (try it yourself first)</b></summary>
//
// | Statement | Reasoning | Displayed |
// |---|---|---|
// | `"A: " + a / b` | `/` outranks `+`, so `7 / 2` runs first. Both are `int`, so the result is `3`. Then `"A: " + 3`. | `A: 3` then newline |
// | `"B: " + a % b` | `%` outranks `+`. `7 % 2` is `1`. | `B: 1` then newline |
// | `"C: " + (a + b) / 3` | Parentheses first: `9`. Then `9 / 3` is `3`. Then concatenate. | `C: 3` then newline |
// | `print("D: ")` | No newline — cursor stays put. | `D: ` |
// | `print(a * b)` | `14`, still no newline. | `14` on the same line |
// | `println(" done")` | Appends, **then** newline. | ` done` |
//
// Final output:
//
// ```
// A: 3
// B: 1
// C: 3
// D: 14 done
// ```
//
// The `D:` line is the one people miss — two `print`s and a `println` all land on one line.
// </details>

// %%
public class TraceMe {
    public static void main(String[] args) {
        int a = 7;
        int b = 2;

        System.out.println("A: " + a / b);
        System.out.println("B: " + a % b);
        System.out.println("C: " + (a + b) / 3);
        System.out.print("D: ");
        System.out.print(a * b);
        System.out.println(" done");
    }
}

TraceMe.main(null);

// %% [markdown]
// ---
//
// # Practice: Fixing the Receipt Printer
//
// Four tasks, in order.
//
// ---
//
// ## Hack 1 — Predict, then run
//
// Fill in your prediction for every row **before** running the cell underneath. Double-click to edit.
//
// | # | Expression | Your prediction | Actual |
// |---|---|---|---|
// | 1 | `1 + 2 + "3"` | | |
// | 2 | `"1" + 2 + 3` | | |
// | 3 | `9 / 2` | | |
// | 4 | `9 % 2` | | |
// | 5 | `9 / 2.0` | | |
// | 6 | `4 + 6 / 2 * 3` | | |
//
// Now run the cell and fill in the last column. Any row where you were wrong is a row worth re-reading.

// %%
public class PredictMe {
    public static void main(String[] args) {
        System.out.println("1. " + (1 + 2 + "3"));
        System.out.println("2. " + ("1" + 2 + 3));
        System.out.println("3. " + (9 / 2));
        System.out.println("4. " + (9 % 2));
        System.out.println("5. " + (9 / 2.0));
        System.out.println("6. " + (4 + 6 / 2 * 3));
    }
}

PredictMe.main(null);

// %% [markdown]
// <details>
// <summary><b>Explanations</b></summary>
//
// 1. `33` — `1 + 2` is arithmetic (both ints), giving `3`. Then `3 + "3"` concatenates into `"33"`.
// 2. `123` — the String comes first, so every `+` after it concatenates.
// 3. `4` — int division truncates `4.5` down to `4`.
// 4. `1` — 2 goes into 9 four times with 1 left over.
// 5. `4.5` — one operand is a `double`, so the result is a `double`.
// 6. `13` — `/` and `*` first, left to right: `6 / 2` is `3`, then `3 * 3` is `9`, then `4 + 9`.
//
// Rows 1 and 2 are the same three values in a different order, and they produce different types of result. That's the concatenation trap.
// </details>

// %% [markdown]
// ---
//
// ## Hack 2 — Repair the receipt
//
// This is the manager's actual program. It has **three** bugs:
//
// - one **syntax** error
// - two **logic** errors (they print, but the numbers are wrong)
//
// It should say the subtotal is `$14` and that each cup gets `12.5` ounces. Run it, fix it, then fill in the bug report.

// %%
public class BrokenReceipt {
    public static void main(String[] args) {
        int quantity    = 2;
        int priceEach   = 6;
        int deliveryFee = 2;
        int totalOunces = 25;
        int cups        = 2;

        System.out.println("=== BYTE-SIZED BOBA ===");
        System.out.println("Items: " + quantity + " x $" + priceEach);
        System.out.println("Subtotal: $" + quantity * priceEach + deliveryFee);
        System.out.println("Ounces per cup: " + totalOunces / cups);
        System.out.println("Ask for the "large" size next time!");
    }
}

BrokenReceipt.main(null);

// %% [markdown]
// **Your bug report** (double-click to edit):
//
// | Bug | What was wrong | Error type | Your fix |
// |---|---|---|---|
// | 1 | | | |
// | 2 | | | |
// | 3 | | | |
//
// <details>
// <summary><b>Check your answers</b></summary>
//
// 1. `"Ask for the "large" size next time!"` — the inner quotes end the string early. **Syntax error.** Fix with escapes: `"Ask for the \"large\" size next time!"`.
// 2. `"Subtotal: $" + quantity * priceEach + deliveryFee` — `*` runs first giving `12`, but then `"...$" + 12` makes a String, so `+ deliveryFee` **concatenates** and prints `$122`. **Logic error.** Fix by parenthesizing the whole calculation: `"Subtotal: $" + (quantity * priceEach + deliveryFee)`.
// 3. `totalOunces / cups` — `25 / 2` is int division, so it prints `12` instead of `12.5`. **Logic error.** Fix by making one operand a double: `totalOunces / 2.0`.
//
// Bug 1 stops the program from compiling at all. Bugs 2 and 3 run happily and hand the customer wrong numbers — exactly the distinction from 1.1.
// </details>

// %% [markdown]
// ---
//
// ## Hack 3 — Print a real receipt
//
// Write a program from scratch that prints a receipt for **3 matcha lattes at $6.50 each**, with a **$2.00 delivery fee**.
//
// Requirements:
//
// - Store the quantity as an `int`, the unit price and fee as `double`s
// - Calculate and print the subtotal and the grand total, with the math **inside parentheses**
// - Use at least one `\n` escape sequence
// - Use at least one `\"` escape sequence somewhere in the receipt
// - Use `print` and `println` together so that at least one displayed line is built from two statements

// %%
public class MyReceipt {
    public static void main(String[] args) {

        // TODO 1: declare quantity (int), unitPrice (double), deliveryFee (double)

        // TODO 2: print a header that uses \n

        // TODO 3: print the item line -- remember parentheses around any math

        // TODO 4: print the subtotal and the grand total

        // TODO 5: print a closing message containing an escaped quotation mark

        // TODO 6: build one line using print + print + println

    }
}

MyReceipt.main(null);

// %% [markdown]
// <details>
// <summary><b>One possible solution</b></summary>
//
// ```java
// public class MyReceipt {
//     public static void main(String[] args) {
//         int    quantity    = 3;
//         double unitPrice   = 6.50;
//         double deliveryFee = 2.00;
//
//         System.out.println("=== BYTE-SIZED BOBA ===\nOrder Receipt");
//         System.out.println(quantity + "x Matcha Latte @ $" + unitPrice);
//         System.out.println("Subtotal: $" + (quantity * unitPrice));
//         System.out.println("Delivery: $" + deliveryFee);
//         System.out.println("TOTAL:    $" + (quantity * unitPrice + deliveryFee));
//
//         System.out.print("Thanks, ");
//         System.out.print("Riley");
//         System.out.println("! Try the \"Brown Sugar Deluxe\" next time.");
//     }
// }
//
// MyReceipt.main(null);
// ```
//
// Note every calculation sits inside its own parentheses. Drop them and the totals turn into concatenated nonsense.
// </details>

// %% [markdown]
// ---
//
// ## Hack 4 — Inventory math with `/` and `%`
//
// The cafe has **47 scoops** of tapioca left. Each drink uses **3 scoops**.
//
// Write a program that prints:
//
// - How many complete drinks can be made
// - How many scoops will be left over
// - The average scoops per drink if you divided all 47 scoops evenly among those drinks, **shown with a decimal**
//
// That third one is the interesting part — think about which operand needs to change type.

// %%
public class TapiocaCheck {
    public static void main(String[] args) {
        int scoopsLeft    = 47;
        int scoopsPerDrink = 3;

        // TODO 1: how many complete drinks? (use /)

        // TODO 2: how many scoops left over? (use %)

        // TODO 3: average scoops per drink as a decimal
        //         hint: at least one operand must be a double

    }
}

TapiocaCheck.main(null);

// %% [markdown]
// <details>
// <summary><b>One possible solution</b></summary>
//
// ```java
// public class TapiocaCheck {
//     public static void main(String[] args) {
//         int scoopsLeft     = 47;
//         int scoopsPerDrink = 3;
//
//         int drinks   = scoopsLeft / scoopsPerDrink;    // 15
//         int leftover = scoopsLeft % scoopsPerDrink;    // 2
//
//         System.out.println("Complete drinks: " + drinks);
//         System.out.println("Scoops left over: " + leftover);
//         double scoopsAsDouble = scoopsLeft;            // storing an int in a double gives 47.0
//         System.out.println("Average per drink: " + (scoopsAsDouble / drinks));
//     }
// }
//
// TapiocaCheck.main(null);
// ```
//
// `47 / 15` as ints would give `3`. Making one side a `double` gives about `3.133`, which is the honest answer — those 2 leftover scoops spread across 15 drinks.
//
// Assigning an `int` into a `double` variable is allowed and automatic, because no information is lost going that direction. (Going the *other* way is the error you met in 1.2.) The `(double)` cast operator does this more directly, and that's Topic 1.5.
// </details>

// %% [markdown]
// ---
//
// # Self-Check: AP-style questions
//
// **1.** What is printed?
//
// ```java
// System.out.print("Boba");
// System.out.print("Tea");
// System.out.println("Time");
// ```
//
// &nbsp;&nbsp;(A) `Boba Tea Time` &nbsp;&nbsp; (B) `BobaTeaTime` &nbsp;&nbsp; (C) three separate lines &nbsp;&nbsp; (D) `Boba` then `TeaTime`
//
// <details><summary>Answer</summary>
//
// **(B)**. `print` adds nothing at all — no space, no line break — so all three land on one line with no separation. Only the final `println` moves the cursor, and it does so *after* printing.
// </details>
//
// ---
//
// **2.** What is printed by `System.out.println("Cups: " + 4 + 5);`?
//
// &nbsp;&nbsp;(A) `Cups: 9` &nbsp;&nbsp; (B) `Cups: 45` &nbsp;&nbsp; (C) `Cups: 4 5` &nbsp;&nbsp; (D) A compile-time error
//
// <details><summary>Answer</summary>
//
// **(B) `Cups: 45`**. Evaluation is left to right: `"Cups: " + 4` produces the String `"Cups: 4"`, and then `+ 5` concatenates again. To get `Cups: 9` you'd need `"Cups: " + (4 + 5)`.
// </details>
//
// ---
//
// **3.** What is the value of `17 / 5 + 17 % 5`?
//
// &nbsp;&nbsp;(A) `3.4` &nbsp;&nbsp; (B) `5` &nbsp;&nbsp; (C) `6` &nbsp;&nbsp; (D) `8`
//
// <details><summary>Answer</summary>
//
// **(B) 5**. `17 / 5` is int division giving `3` (the `.4` is discarded, not rounded). `17 % 5` is `2`. Then `3 + 2` is `5`. Both `/` and `%` outrank `+`.
// </details>
//
// ---
//
// **4.** Which expression evaluates to `4.5`?
//
// &nbsp;&nbsp;(A) `9 / 2` &nbsp;&nbsp; (B) `9 % 2` &nbsp;&nbsp; (C) `9 / 2.0` &nbsp;&nbsp; (D) `9.0 % 2`
//
// <details><summary>Answer</summary>
//
// **(C)**. One operand being a `double` makes the whole result a `double`. (A) truncates to `4`, (B) is the remainder `1`, and (D) is a remainder operation giving `1.0`.
// </details>
//
// ---
//
// **5.** Which statement correctly prints `He said "hello"` including the quotation marks?
//
// &nbsp;&nbsp;(A) `System.out.println("He said "hello"");`
// &nbsp;&nbsp;(B) `System.out.println("He said \"hello\"");`
// &nbsp;&nbsp;(C) `System.out.println("He said \\hello\\");`
// &nbsp;&nbsp;(D) `System.out.println("He said /"hello/"");`
//
// <details><summary>Answer</summary>
//
// **(B)**. The escape sequence `\"` produces a literal quotation mark. (A) ends the string early and won't compile, (C) prints backslashes, and (D) uses a forward slash, which has no escape meaning.
// </details>
//
// ---
//
// **6.** What is printed?
//
// ```java
// int a = 12;
// int b = 5;
// System.out.println(a + b / 2 * 3);
// ```
//
// &nbsp;&nbsp;(A) `25` &nbsp;&nbsp; (B) `18` &nbsp;&nbsp; (C) `24` &nbsp;&nbsp; (D) `13`
//
// <details><summary>Answer</summary>
//
// **(B) 18**. `/` and `*` share the top priority and run left to right: `5 / 2` is `2` (int division), then `2 * 3` is `6`, then `12 + 6` is `18`. Answer (A) comes from doing `5 / 2` as `2.5`; answer (C) comes from evaluating `2 * 3` before the division.
// </details>
//
// ---
//
// **7.** A program computes `int average = totalOunces / cups;` where `totalOunces` is 25 and `cups` is 2. The program compiles, runs, and prints `12`. This is an example of a:
//
// &nbsp;&nbsp;(A) Compile-time error &nbsp;&nbsp; (B) Run-time error &nbsp;&nbsp; (C) Logic error &nbsp;&nbsp; (D) Correct program
//
// <details><summary>Answer</summary>
//
// **(C)**. It compiles and runs without complaint but produces a wrong answer — the definition of a logic error. Integer division silently discarded the `.5`. This is why "it ran without errors" never means "it's correct."
// </details>

// %% [markdown]
// ---
//
// # Closing time
//
// ### Vocabulary to know cold
//
// | Term | One-line definition |
// |---|---|
// | `System.out.print` | Displays output and leaves the cursor on the same line |
// | `System.out.println` | Displays output, then moves the cursor to a new line |
// | String literal | Fixed text written inside double quotation marks |
// | Escape sequence | A backslash pair like `\"`, `\\`, or `\n` that represents a special character |
// | Concatenation | Using `+` to join a String with another value, converting it to text |
// | Integer division | `int / int` produces an `int`; the fractional part is discarded, not rounded |
// | Remainder operator `%` | Gives what's left over after integer division |
// | Operator precedence | `( )` first, then `*` `/` `%`, then `+` `-`; ties break left to right |
//
// ### The five things that will show up on the exam
//
// 1. `print` leaves the cursor; `println` moves it.
// 2. `+` chains evaluate **left to right** — once a String appears, everything after it concatenates.
// 3. `int / int` **truncates**. `7 / 2` is `3`.
// 4. One `double` operand makes the whole result a `double`.
// 5. `%` has the **same** priority as `*` and `/`, not lower.
//
// ### Before you submit, check that you:
//
// - [ ] Ran every code cell, including the two that fail on purpose
// - [ ] Filled in your predictions in Hack 1 **before** running the cell
// - [ ] Got Hack 2 printing `$14` and `12.5`, and labeled all three bugs by type
// - [ ] Wrote Hack 3 meeting all six requirements
// - [ ] Solved Hack 4 including the decimal average
// - [ ] Attempted all seven self-check questions before revealing answers
//
// ### Next up
//
// **1.4 — Assignment Statements and Input.** Every value in this notebook was typed into the source code by you. Next shift the cafe gets a real order screen: you'll meet `Scanner` and let an actual customer type their order while the program is running.
//
// > *Correction from Lesson 1.2:* that notebook pointed to String objects as the next topic. String work is actually Topic **1.15 — String Manipulation**, near the end of Unit 1. Topic 1.3 is Expressions and Output, which is what you just finished.
//
// See you at the next shift 🧋
