// %% [raw]
// ---
// layout: post
// title: 1.8 Documentation with Comments
// description: Boba Cafe Series, Lesson 8. Single-line, block, and Javadoc comments, writing comments worth reading, and method preconditions and postconditions.
// categories: [AP CSA, Unit 1]
// permalink: /csa/unit1/1-8
// toc: true
// comments: true
// ---

// %% [markdown]
// # 1.8 — Documentation with Comments 🧋
//
// ### AP CSA · Unit 1: Using Objects and Methods
// **Boba Cafe Series · Lesson 8**
//
// ---
//
// > **Setup note:** every code cell runs on the **IJava kernel** (Java 17+). Check that the kernel picker says *Java*. Each cell declares a class and then calls it with `ClassName.main(null);`.
//
// > **A small preview:** a few cells below contain short **methods** of their own alongside `main`. You'll learn to write methods properly in 1.9 and Unit 3 — here you only need to *read* them, since documenting a method is what this whole lesson is about.

// %% [markdown]
// ## Now you're the supplier
//
// Last lesson you read other people's documentation. You used `Math.pow` correctly without ever seeing its source code, because somebody wrote a clear description of what it needs and what it gives back.
//
// Today you flip sides.
//
// The manager drops a printout on the counter:
//
// > "Someone wrote the register software two years ago and left. There's a method called `calc()` that returns a number. Nobody knows what the number means, whether it includes tax, or what happens if you pass it a zero. Everyone's afraid to touch it. Don't ever do this to us again."
//
// **Undocumented code isn't just inconvenient — it's code nobody can safely change.** The compiler doesn't care about comments at all. Comments exist entirely for humans, including the version of you that comes back in six months having forgotten everything.
//
// ### What you'll be able to do by the end
//
// | # | Objective | CED reference |
// |---|---|---|
// | 1 | Use all three Java comment types correctly | 1.8.A.1 |
// | 2 | Explain what Javadoc comments generate and why that matters | 1.8.A.1 |
// | 3 | Write comments that explain **why**, not restate **what** | 1.8.A |
// | 4 | Identify and write a **precondition** | 1.8.A.2 |
// | 5 | Identify and write a **postcondition** | 1.8.A.3 |
// | 6 | Explain who is responsible for satisfying a precondition | 1.8.A.2 |

// %% [markdown]
// ---
//
// ## Part 1 — The compiler ignores every word
//
// Before anything else, prove it to yourself.
//
// Comments are stripped out before your code is compiled. You can write complete nonsense inside one and the program still runs perfectly. Comments never execute, never affect output, and never slow anything down.

// %%
public class CommentsIgnored {
    public static void main(String[] args) {
        // This line does absolutely nothing.

        /* Neither does this one, even though it contains
           total gibberish:  %%%$$$ int int int ))));;;;
           The compiler never even looks at it. */

        System.out.println("Only this line produced output.");

        // System.out.println("This statement is commented out, so it never runs.");
    }
}

CommentsIgnored.main(null);

// %% [markdown]
// That last line shows a second use for comments: **temporarily disabling code** while you test something. You've already done this a few times in earlier lessons.

// %% [markdown]
// ---
//
// ## Part 2 — The three comment types
//
// | Type | Syntax | Use it for |
// |---|---|---|
// | **Single-line** | `// note` | A quick note about one line or a short section |
// | **Block** | `/* note */` | Explanations spanning several lines; disabling chunks of code |
// | **Javadoc** | `/** note */` | Describing a class or method — **generates API documentation** |
//
// All three are ignored at run time. The difference is who reads them and how.
//
// That third one is the important one, and here's why it's different in kind rather than just in style:
//
// > **Javadoc comments are read by a tool.** The `javadoc` program that ships with Java scans `/** */` comments and produces browsable HTML documentation automatically.
//
// This is the direct answer to something from Lesson 1.7. When you read the documentation for `Math.sqrt`, you were reading **generated Javadoc**. Somebody at Oracle wrote a `/** */` comment above the method, and a tool turned it into the page you read. The API you consumed last lesson and the comments you write today are the same thing at two different stages.
//
// A Javadoc comment goes **directly above** whatever it describes — a class, a method, or a constant.

// %%
/**
 * DrinkPricer calculates order totals for Byte-Sized Boba.
 * A Javadoc comment above a class describes the whole class.
 */
public class DrinkPricer {

    /** The sales tax rate charged at all locations. */
    public static final double TAX_RATE = 0.0775;

    public static void main(String[] args) {
        // Single-line comment: a quick note
        double subtotal = 11.50;

        /* Block comment: use this when the explanation
           genuinely needs more than one line to make sense. */
        double total = subtotal + subtotal * TAX_RATE;

        System.out.println("Subtotal: $" + subtotal);
        System.out.println("Total:    $" + total);
    }
}

DrinkPricer.main(null);

// %% [markdown]
// > **One syntax gotcha:** block comments **do not nest**. If you write `/*` inside another `/* */`, the first `*/` ends the whole thing and the leftovers become code that won't compile. This bites people who try to comment out a section that already contains a block comment.

// %% [markdown]
// ---
//
// ## Part 3 — Comments worth reading
//
// Writing a comment is easy. Writing a *useful* one takes judgment.
//
// The most common beginner mistake is a comment that simply restates the code in English:
//
// ```java
// cups--;             // decrease cups by 1
// ```
//
// Anyone reading that already knows `--` subtracts one. The comment added nothing, and now there are **two** things to keep updated instead of one. If the code changes and the comment doesn't, the comment becomes an active lie.
//
// > **The rule: code says WHAT. Comments say WHY.**
//
// Compare these two programs. They are **identical code** with identical output.

// %%
public class BadComments {
    public static void main(String[] args) {
        int cups = 40;                    // set cups to 40
        cups--;                           // decrease cups by 1
        cups /= 2;                        // divide cups by 2
        System.out.println("Cups: " + cups);   // print cups
    }
}

BadComments.main(null);

// %%
public class GoodComments {
    public static void main(String[] args) {
        int cups = 40;    // morning delivery arrives as one 40-cup case
        cups--;           // one cup is always used to calibrate the sealing machine
        cups /= 2;        // stock is split evenly between counter and drive-thru

        System.out.println("Cups for the front counter: " + cups);
    }
}

GoodComments.main(null);

// %% [markdown]
// Same instructions, same `19`. But only the second version tells you that the sealer eats a cup, or that the halving is a policy decision rather than a math trick. **The first program's comments could be deleted with zero information lost. The second program's could not.**
//
// ### A checklist for good comments
//
// Comment when you're explaining:
//
// - **Why** a decision was made — `// tax is added before the discount per state law`
// - A **non-obvious** consequence — `// integer division: partial dollars earn no points`
// - A **unit or format** the code can't show — `// temperature in degrees Fahrenheit`
// - A **precondition or postcondition** (Parts 5 and 6)
//
// Don't comment:
//
// - Anything the code already says plainly
// - Something you can fix with a better variable name instead
//
// That last one deserves emphasis. `int d = 7; // days until restock` is worse than `int daysUntilRestock = 7;` with no comment at all. **A good name beats a good comment**, because a name can't fall out of sync with the code.

// %% [markdown]
// ---
//
// ## Part 4 — Javadoc tags
//
// Javadoc comments use structured **tags** so the generated documentation can be organized consistently.
//
// | Tag | Describes |
// |---|---|
// | `@param name` | One input the method needs, and any restrictions on it |
// | `@return` | What the method gives back |
//
// A complete method Javadoc has a short description first, then one `@param` per parameter, then `@return`.
//
// Read the comment below and notice you could use `calculateTotal` correctly **without reading a single line of its body** — which is exactly the test of good documentation.

// %%
public class PriceCalculator {

    /**
     * Calculates the total cost of an order, including sales tax.
     *
     * @param quantity the number of drinks ordered
     * @param unitPrice the price of one drink, in dollars
     * @return the total cost in dollars with 7.75% tax applied
     */
    public static double calculateTotal(int quantity, double unitPrice) {
        double subtotal = quantity * unitPrice;
        return subtotal + subtotal * 0.0775;
    }

    public static void main(String[] args) {
        System.out.println("2 drinks at $5.75: $" + calculateTotal(2, 5.75));
        System.out.println("3 drinks at $6.50: $" + calculateTotal(3, 6.50));
    }
}

PriceCalculator.main(null);

// %% [markdown]
// Notice what the documentation had to specify that the method name alone could never tell you: **the total already includes tax.** Without that sentence, a caller might reasonably add tax a second time.

// %% [markdown]
// ---
//
// ## Part 5 — Preconditions
//
// > **Definition:** A **precondition** is a condition that must be true *before* a method runs in order for the method to behave as expected.
//
// The cafe version: the sealing machine's instructions say *"the machine must be switched on and a cup must be in the cradle."* Those are preconditions. Press the button with an empty cradle and you get a mess — and that's not the machine's fault.
//
// Here's the part the AP exam tests, and it surprises almost everyone:
//
// > **The method is not required to check whether the precondition is true. Satisfying it is the caller's responsibility.**
//
// A precondition is a **contract**. It says: *"if you give me valid input, I promise to work. If you don't, all bets are off — I might crash, or I might just hand you garbage."*
//
// Read the method below, then look at what happens when the contract is broken.

// %%
public class BillSplitter {

    /**
     * Splits an order total evenly among a group of people.
     *
     * Precondition: people > 0
     *
     * @param total the order total in dollars
     * @param people the number of people splitting the bill
     * @return each person's share, in dollars
     */
    public static double splitBill(double total, int people) {
        return total / people;      // no check for zero -- see the precondition
    }

    public static void main(String[] args) {
        System.out.println("$24.00 among 4: $" + splitBill(24.00, 4));
        System.out.println("$24.00 among 3: $" + splitBill(24.00, 3));

        // Precondition VIOLATED. The method does not protect you.
        System.out.println("$24.00 among 0: $" + splitBill(24.00, 0));
    }
}

BillSplitter.main(null);

// %% [markdown]
// Look at that last line: **`Infinity`**. Not an error message. Not a crash. A value that is mathematically meaningless as a per-person share, printed onto a receipt as though it were a dollar amount.
//
// That's the roundoff-and-range material from 1.5 doing exactly what it warned about: `double` division by zero produces `Infinity` rather than throwing. Had `total` been an `int`, this same call would have thrown an `ArithmeticException` instead — a loud failure rather than a silent one.
//
// Either way, **the method behaved correctly.** It never promised anything for `people == 0`. The caller broke the contract.
//
// > **On the AP exam:** if documentation states a precondition, assume it is satisfied. Do not write code to validate it unless the question explicitly asks you to.
//
// Preconditions usually restrict:
//
// - **Ranges** — `score >= 0 && score <= 100`
// - **Non-zero divisors** — `people > 0`
// - **Non-null references** — `name is not null`
// - **Relationships between parameters** — `startIndex <= endIndex`

// %% [markdown]
// ---
//
// ## Part 6 — Postconditions
//
// > **Definition:** A **postcondition** is a condition that is true *after* the method finishes. It's what the method **promises**.
//
// If a precondition is what the method demands, a postcondition is what it guarantees in return. Together they form the two halves of the contract:
//
// ```
//    ┌────────────────────────────────────────────────┐
//    │  PRECONDITION          POSTCONDITION           │
//    │  what the CALLER       what the METHOD         │
//    │  must guarantee   ──►  guarantees back         │
//    │                                                │
//    │  "people > 0"          "returns each share"    │
//    └────────────────────────────────────────────────┘
// ```
//
// Postconditions typically describe the **return value**, any **change to an object's state**, or a guaranteed property of the result.
//
// The method below has a postcondition that captures something genuinely non-obvious — and it's the kind of detail that causes bugs when it goes undocumented.

// %%
public class TrayPacker {

    /**
     * Counts how many completely full trays a batch of cups will fill.
     *
     * Precondition:  cups >= 0 and cupsPerTray > 0
     * Postcondition: returns a value >= 0; leftover cups that do not
     *                fill a complete tray are NOT counted
     *
     * @param cups the total number of cups to pack
     * @param cupsPerTray how many cups one tray holds
     * @return the number of completely filled trays
     */
    public static int fullTrays(int cups, int cupsPerTray) {
        return cups / cupsPerTray;
    }

    public static void main(String[] args) {
        System.out.println("20 cups, 6 per tray -> " + fullTrays(20, 6) + " full trays");
        System.out.println(" 5 cups, 6 per tray -> " + fullTrays(5, 6) + " full trays");
        System.out.println("12 cups, 6 per tray -> " + fullTrays(12, 6) + " full trays");
    }
}

TrayPacker.main(null);

// %% [markdown]
// Five cups returned **zero** trays. Without that postcondition spelled out, a caller might reasonably expect `1` (a partly filled tray) and ship five cups to a customer who ordered a full one.
//
// The postcondition documents a consequence of integer division that the method name `fullTrays` only hints at. **This is the single most valuable thing documentation does: state the surprising part out loud.**

// %% [markdown]
// ---
//
// # Practice: Writing the Manual
//
// Four tasks, in order.
//
// ---
//
// ## Hack 1 — Useful or useless?
//
// For each comment, mark it useful or useless. If useless, either rewrite it into something worth reading or say what should replace it. Double-click to edit.
//
// | # | Code and comment | Useful? | Your fix |
// |---|---|---|---|
// | 1 | `total += price;  // add price to total` | | |
// | 2 | `stock -= 2;  // two cups are reserved for staff samples` | | |
// | 3 | `int t = 90;  // steeping time` | | |
// | 4 | `cups /= 2;  // integer division: an odd cup is discarded` | | |
// | 5 | `x++;  // increment x` | | |
// | 6 | `price *= 0.9;  // 10% student discount, verified at the register` | | |
//
// <details>
// <summary><b>Check your answers</b></summary>
//
// 1. **Useless.** It restates the operator. Delete it.
// 2. **Useful.** It explains *why* two, which the code can never show.
// 3. **Useless as written** — but the problem is the *name*, not the comment. Replace with `int steepingTimeSeconds = 90;` and drop the comment. A good name beats a good comment.
// 4. **Useful.** It flags a non-obvious consequence (truncation from 1.5) that a reader could easily miss.
// 5. **Useless.** Pure restatement. Delete it.
// 6. **Useful.** It gives the business reason for the magic number `0.9`.
//
// The pattern: comments 2, 4, and 6 all answer **why**. Comments 1 and 5 answer **what**, which the code already did.
// </details>

// %% [markdown]
// ---
//
// ## Hack 2 — Document the abandoned method
//
// Here is the method the manager complained about. It works, but nobody knows what it promises.
//
// Your job: write a complete Javadoc comment above it, containing:
//
// - A one-sentence description
// - One `@param` for each parameter
// - One `@return`
// - A **precondition**
// - A **postcondition** that warns about the non-obvious behavior
//
// Run the cell first and study the output before you write. The `1750, 2` call is the one that reveals the surprise.

// %%
public class LoyaltyProgram {

    // TODO: replace this line with a complete Javadoc comment
    public static int pointsEarned(int centsSpent, int bonusMultiplier) {
        return (centsSpent / 100) * bonusMultiplier;
    }

    public static void main(String[] args) {
        System.out.println("Spent 1750 cents, 2x bonus: " + pointsEarned(1750, 2));
        System.out.println("Spent 1799 cents, 2x bonus: " + pointsEarned(1799, 2));
        System.out.println("Spent   99 cents, 2x bonus: " + pointsEarned(99, 2));
    }
}

LoyaltyProgram.main(null);

// %% [markdown]
// <details>
// <summary><b>One possible solution</b></summary>
//
// Run the cell and look at the middle line: spending **1799** cents earns the same points as spending **1750**. And 99 cents earns **nothing at all**. That's the behavior your documentation must warn about.
//
// ```java
// /**
//  * Calculates loyalty points earned for a purchase.
//  * One point is awarded per whole dollar spent, then multiplied by the bonus rate.
//  *
//  * Precondition:  centsSpent >= 0 and bonusMultiplier > 0
//  * Postcondition: returns a value >= 0. Because only whole dollars count,
//  *                any leftover cents earn no points -- spending 199 cents
//  *                earns the same as spending 100 cents.
//  *
//  * @param centsSpent the purchase amount, in cents
//  * @param bonusMultiplier the promotional multiplier applied to base points
//  * @return the total loyalty points earned
//  */
// public static int pointsEarned(int centsSpent, int bonusMultiplier) {
//     return (centsSpent / 100) * bonusMultiplier;
// }
// ```
//
// The postcondition is the whole point of this exercise. `centsSpent / 100` is **integer division**, so partial dollars vanish. A customer service rep reading only the method name would never guess that, and would spend an afternoon arguing with a customer about a missing point.
// </details>

// %% [markdown]
// ---
//
// ## Hack 3 — Reading the contract
//
// Study this documented method, then answer the questions below. **You are not given the method body**, which is the point — good documentation should be enough.
//
// ```java
// /**
//  * Returns the letter grade for a barista's certification score.
//  *
//  * Precondition:  score >= 0 and score <= 100
//  * Postcondition: returns exactly one of "A", "B", "C", "D", or "F"
//  *
//  * @param score the barista's exam score
//  * @return the corresponding letter grade
//  */
// public static String getGrade(int score)
// ```
//
// Answer in the markdown below (double-click to edit):
//
// 1. What must be true before you call this method?
// 2. If you call `getGrade(150)`, whose fault is the resulting behavior — the method's or the caller's?
// 3. Is the method required to check that `score` is between 0 and 100?
// 4. Can `getGrade` ever return `"E"`? How do you know without seeing the code?
// 5. Name one thing this documentation does **not** tell you.
//
// **Your answers:**
//
// 1.
//
// 2.
//
// 3.
//
// 4.
//
// 5.
//
// <details>
// <summary><b>Check your answers</b></summary>
//
// 1. `score` must be at least `0` and at most `100`. That's the stated precondition.
//
// 2. **The caller's.** The precondition was published in advance; passing `150` breaks the contract. The method never promised anything for out-of-range input.
//
// 3. **No.** A method is not expected to verify its own preconditions. It may check, but it is not required to, and on the AP exam you should assume preconditions hold unless asked to validate them.
//
// 4. **No.** The postcondition guarantees the return value is exactly one of `"A"`, `"B"`, `"C"`, `"D"`, or `"F"`. That's a promise about the output, so you can rely on it without reading the implementation.
//
// 5. Several valid answers: the **cutoff scores** for each grade, whether the boundaries are inclusive, and what happens if the precondition is violated. The documentation deliberately hides *how* the grade is computed — that's abstraction from 1.7, and it means the cutoffs could change without breaking any caller.
// </details>

// %% [markdown]
// ---
//
// ## Hack 4 — Document your own method
//
// Below is a working method with no documentation at all. Write a full Javadoc comment for it, then answer the follow-up question.
//
// Run it first. Pay close attention to the third call.

// %%
public class RestockChecker {

    // TODO: write a complete Javadoc comment here
    //       (description, @param for each, @return, Precondition, Postcondition)
    public static int daysUntilEmpty(int cupsInStock, int cupsPerDay) {
        return cupsInStock / cupsPerDay;
    }

    public static void main(String[] args) {
        System.out.println("100 cups, 30/day -> " + daysUntilEmpty(100, 30) + " days");
        System.out.println(" 60 cups, 30/day -> " + daysUntilEmpty(60, 30) + " days");
        System.out.println(" 20 cups, 30/day -> " + daysUntilEmpty(20, 30) + " days");
    }
}

RestockChecker.main(null);

// %% [markdown]
// **Follow-up question:** the third call reports `0` days. Explain why a manager relying on this method could run out of cups unexpectedly, and write the one sentence of documentation that would prevent that.
//
// **Your answer:**
//
// <details>
// <summary><b>One possible solution</b></summary>
//
// ```java
// /**
//  * Estimates how many full days the current cup supply will last.
//  *
//  * Precondition:  cupsInStock >= 0 and cupsPerDay > 0
//  * Postcondition: returns a value >= 0. The result counts only COMPLETE days;
//  *                a partial day's supply is reported as 0, so a return value
//  *                of 0 means "less than one full day remains," not "empty."
//  *
//  * @param cupsInStock the number of cups currently in inventory
//  * @param cupsPerDay the average number of cups used per day
//  * @return the number of complete days the supply will last
//  */
// public static int daysUntilEmpty(int cupsInStock, int cupsPerDay) {
//     return cupsInStock / cupsPerDay;
// }
// ```
//
// **Why the manager gets burned:** `20 / 30` is integer division, which truncates to `0`. A manager who reads "0 days" as "we're out" might place an emergency order — or, worse, one who reads `100 / 30` as "3 days" plans for exactly 3 days and doesn't realize the leftover 10 cups were silently discarded from the estimate.
//
// **The one sentence that prevents it:** state in the postcondition that only *complete* days are counted and that partial supply is rounded down.
//
// Notice that Hacks 2 and 4 have the same root cause. Integer division keeps producing surprising results, and in every case the fix is the same: **say the surprising part out loud in the documentation.**
// </details>

// %% [markdown]
// ---
//
// # Self-Check: AP-style questions
//
// **1.** Which comment type is used to generate API documentation?
//
// &nbsp;&nbsp;(A) `// comment` &nbsp;&nbsp; (B) `/* comment */` &nbsp;&nbsp; (C) `/** comment */` &nbsp;&nbsp; (D) `# comment`
//
// <details><summary>Answer</summary>
//
// **(C)**. The `/** */` form is a Javadoc comment, which the `javadoc` tool reads to produce HTML documentation. (D) isn't valid Java at all.
// </details>
//
// ---
//
// **2.** What effect do comments have on a running program?
//
// &nbsp;&nbsp;(A) They print to the console when reached
// &nbsp;&nbsp;(B) They slow execution slightly
// &nbsp;&nbsp;(C) They have no effect; the compiler ignores them
// &nbsp;&nbsp;(D) They are stored in memory as Strings
//
// <details><summary>Answer</summary>
//
// **(C)**. Comments are stripped before compilation. They never execute, produce output, or occupy memory at run time.
// </details>
//
// ---
//
// **3.** A method is documented with `Precondition: index >= 0`. A programmer calls it with `index = -5`. Which statement is correct?
//
// &nbsp;&nbsp;(A) The method must throw an exception
// &nbsp;&nbsp;(B) The method is required to check the value and reject it
// &nbsp;&nbsp;(C) The method's behavior is not guaranteed; the caller violated the contract
// &nbsp;&nbsp;(D) The compiler will refuse to compile the call
//
// <details><summary>Answer</summary>
//
// **(C)**. A precondition places the responsibility on the **caller**. The method is not required to check it, and when it's violated the method makes no promises at all — it might crash, or it might silently return nonsense.
// </details>
//
// ---
//
// **4.** Which is the best description of a postcondition?
//
// &nbsp;&nbsp;(A) What must be true before the method is called
// &nbsp;&nbsp;(B) What is guaranteed to be true after the method finishes
// &nbsp;&nbsp;(C) A comment describing the method's parameters
// &nbsp;&nbsp;(D) An error message shown when input is invalid
//
// <details><summary>Answer</summary>
//
// **(B)**. A postcondition is the method's promise — typically about the return value or a change in state. (A) describes a precondition.
// </details>
//
// ---
//
// **5.** Which comment is most useful?
//
// &nbsp;&nbsp;(A) `count++;  // increment count by 1`
// &nbsp;&nbsp;(B) `count++;  // add one to the counter`
// &nbsp;&nbsp;(C) `count++;  // a refunded drink still counts toward the daily total`
// &nbsp;&nbsp;(D) `count++;  // this is an increment operator`
//
// <details><summary>Answer</summary>
//
// **(C)**. It explains **why** the increment happens, which the code cannot show. (A), (B), and (D) all restate what `++` does, which any reader already knows.
// </details>
//
// ---
//
// **6.** Consider this documentation:
//
// ```
// Precondition:  cups >= 0 and perTray > 0
// Postcondition: returns a value >= 0; leftover cups are not counted
// ```
//
// What does `fullTrays(11, 4)` return?
//
// &nbsp;&nbsp;(A) `2.75` &nbsp;&nbsp; (B) `3` &nbsp;&nbsp; (C) `2` &nbsp;&nbsp; (D) Cannot be determined
//
// <details><summary>Answer</summary>
//
// **(C) 2**. The postcondition says leftover cups aren't counted, so only complete trays are reported: 4 goes into 11 twice with 3 left over. (A) ignores that the return type is an `int` and that leftovers are excluded; (B) rounds up, which the postcondition rules out.
// </details>
//
// ---
//
// **7.** Why does a Javadoc comment belong directly above the method it describes?
//
// &nbsp;&nbsp;(A) Java requires it there or the code won't compile
// &nbsp;&nbsp;(B) So the `javadoc` tool can associate the comment with that method
// &nbsp;&nbsp;(C) Because comments placed elsewhere are executed
// &nbsp;&nbsp;(D) To reduce the size of the compiled file
//
// <details><summary>Answer</summary>
//
// **(B)**. Placement is what tells the tool which method the comment documents. The compiler itself is indifferent — a misplaced Javadoc comment still compiles, it just produces wrong or missing documentation.
// </details>
//
// ---
//
// **8.** A programmer renames a variable from `t` to `steepingTimeSeconds` and deletes the comment `// steeping time`. Is this a good change?
//
// &nbsp;&nbsp;(A) No — deleting comments always reduces clarity
// &nbsp;&nbsp;(B) No — comments are required on every variable
// &nbsp;&nbsp;(C) Yes — a descriptive name conveys the same information and cannot fall out of sync
// &nbsp;&nbsp;(D) Yes — but only because shorter files compile faster
//
// <details><summary>Answer</summary>
//
// **(C)**. A self-documenting name carries the meaning in the code itself. A comment can drift out of date when the code changes; a variable name used throughout the program cannot.
// </details>

// %% [markdown]
// ---
//
// # Closing time
//
// ### Vocabulary to know cold
//
// | Term | One-line definition |
// |---|---|
// | Comment | Text ignored by the compiler, written for human readers |
// | Single-line comment | `// text` — runs to the end of the line |
// | Block comment | `/* text */` — spans multiple lines; does not nest |
// | Javadoc comment | `/** text */` — used to generate API documentation |
// | `@param` | Javadoc tag describing one method parameter |
// | `@return` | Javadoc tag describing what a method gives back |
// | Precondition | What must be true **before** a method runs; the **caller's** responsibility |
// | Postcondition | What is guaranteed true **after** a method finishes; the method's promise |
//
// ### The five things that will show up on the exam
//
// 1. Comments are **ignored by the compiler** — no output, no effect, no cost.
// 2. `/** */` is Javadoc and **generates API documentation**; `//` and `/* */` do not.
// 3. A **precondition** is what the caller must guarantee.
// 4. **A method is not required to check its preconditions.** Assume they hold.
// 5. A **postcondition** is what the method promises — usually about the return value.
//
// ### The one-sentence version
//
// > **Code says what. Comments say why. Preconditions say what you owe the method. Postconditions say what it owes you.**
//
// ### Before you submit, check that you:
//
// - [ ] Ran every code cell top to bottom
// - [ ] Classified all six comments in Hack 1 and rewrote the useless ones
// - [ ] Wrote a complete Javadoc for Hack 2, including the integer-division postcondition
// - [ ] Answered all five contract questions in Hack 3
// - [ ] Documented `daysUntilEmpty` in Hack 4 and explained the `0` days trap
// - [ ] Attempted all eight self-check questions before revealing answers
//
// ### Next up
//
// **1.9 — Method Signatures.** You've now read several methods and written documentation for them, but you've been taking the first line — `public static int pointsEarned(int centsSpent, int bonusMultiplier)` — largely on faith. Next shift you take that line apart piece by piece, learn what a **signature** is, and figure out how Java decides which method you meant when two of them share a name.
//
// See you at the next shift 🧋
